# %% [markdown]
# # Ещё признаки

# %%
from nltk.stem import SnowballStemmer

snowball = SnowballStemmer(language="russian")

# %%
def LCS_string(s1, s2):
    s1 = s1.lower()
    s2 = s2.lower()
    s1 = snowball.stem(s1)
    s2 = snowball.stem(s2)
    
    d = [[0] * (len(s2) + 1) for _ in range(len(s1) + 1)]
    max_val, index_i = 0, 0
    for i in range(len(s1) + 1):
        for j in range(len(s2) + 1):
            if i and j and s1[i - 1] == s2[j - 1]:
                d[i][j] = d[i - 1][j - 1] + 1
            if d[i][j] > max_val:
                max_val = d[i][j]
                index_i = i
                index_j = j
    
    return s1[index_i - max_val : index_i]

# %%
print(LCS_string('subsequence', 'subeuencs'))
# Out:
# uenc

# %%
def LCS(s1, s2):
    return len(LCS_string(s1, s2))

# %%
def levenshtein_distance(s1, s2):
    s1 = s1.lower()
    s2 = s2.lower()
    s1 = snowball.stem(s1)
    s2 = snowball.stem(s2)
    
    d = [[0] * (len(s2) + 1) for _ in range(len(s1) + 1)]
    for i in range(len(s1) + 1):
        for j in range(len(s2) + 1):
            if i == 0:
                d[i][j] = j
            elif j == 0:
                d[i][j] = i
            else:
                d[i][j] = min(d[i][j - 1] + 1, d[i - 1][j] + 1)
                delta = 0 if s1[i - 1] == s2[j - 1] else 1
                d[i][j] = min(d[i][j], d[i - 1][j - 1] + delta)
                
    return d[len(s1)][len(s2)]

# %%
print(levenshtein_distance('Levenshtein', 'Lenvinsten'))
# Out:
# 4

# %%
def levenshtein_similarity(s1, s2):
    dist = levenshtein_distance(s1, s2)
    if dist:
        return 1 / dist
    else:
        return 1

# %%
print(levenshtein_similarity('Levenshtein', 'Lenvinsten'))
# Out:
# 0.25

# %%
def before_lcs(s1, s2):
    lcs_str = LCS_string(s1, s2)
    ind1 = s1.find(lcs_str)
    ind2 = s2.find(lcs_str)
    
    return abs(ind1 - ind2)

# %%
print(before_lcs('subsequence', 'subeuencs'))
# Out:
# 2

# %%
def after_lcs(s1, s2):
    lcs_str = LCS_string(s1, s2)
    after1 = len(s1) - s1.find(lcs_str) - len(lcs_str)
    after2 = len(s2) - s2.find(lcs_str) - len(lcs_str)
    
    return abs(after1 - after2)

# %%
print(after_lcs('subsequence', 'subeuencs'))
# Out:
# 0

# %%
import spacy

nlp = spacy.load('ru_core_news_lg')

# %%
def word_similarity(s1, s2):
    tokens = nlp(s1 + ' ' + s2)
    if tokens[0].has_vector and tokens[1].has_vector:
        return tokens[0].similarity(tokens[1])
    else:
        return None

# %%
print(word_similarity('мама', 'мамочка'))
# Out:
# 0.7435692

# %% [markdown]
# Загрузим датасеты, объединим их, добавим признаки:

# %%
import pandas as pd
from sklearn.utils import shuffle

cognates_data = pd.read_csv('cognates_dataset_clean.csv', encoding='cp1251')
non_cognates_data = pd.read_csv('non-cognates_dataset_bigger.csv', encoding='cp1251')
non_cognates_data.head()
# Out:
#    Unnamed: 0 first_word   second_word  Levenshtein  longest_common_substr  \
# 0           0    А-конто     Телеэкран            9                      1
# 1           1    А-конто  Коллективизм           11                      1
# 2           2    А-конто       Семерик            7                      1
# 3           3    А-конто      Скрючить            7                      1
# 4           4    А-конто     Эозойский            8                      1
#
#    longest_common_subs
# 0                    2
# 1                    2
# 2                    1
# 3                    2
# 4                    2

# %%
cognates_data.pop('Unnamed: 0')
cognates_data.head()
# Out:
#   first_word second_word  Levenshtein  longest_common_substr  \
# 0    А-конто      Аканье            4                      1
# 1    А-конто       Акать            4                      1
# 2    А-конто     Акающий            6                      1
# 3    А-конто        Ашка            5                      1
# 4    А-конто     Бамовец            6                      1
#
#    longest_common_subs
# 0                    3
# 1                    3
# 2                    2
# 3                    2
# 4                    1

# %%
non_cognates_data.pop('Unnamed: 0')
non_cognates_data.head()
# Out:
#   first_word   second_word  Levenshtein  longest_common_substr  \
# 0    А-конто     Телеэкран            9                      1
# 1    А-конто  Коллективизм           11                      1
# 2    А-конто       Семерик            7                      1
# 3    А-конто      Скрючить            7                      1
# 4    А-конто     Эозойский            8                      1
#
#    longest_common_subs
# 0                    2
# 1                    2
# 2                    1
# 3                    2
# 4                    2

# %%
cognates_data['class'] = 1
non_cognates_data['class'] = 0
non_cognates_data.head()
# Out:
#   first_word   second_word  Levenshtein  longest_common_substr  \
# 0    А-конто     Телеэкран            9                      1
# 1    А-конто  Коллективизм           11                      1
# 2    А-конто       Семерик            7                      1
# 3    А-конто      Скрючить            7                      1
# 4    А-конто     Эозойский            8                      1
#
#    longest_common_subs  class
# 0                    2      0
# 1                    2      0
# 2                    1      0
# 3                    2      0
# 4                    2      0

# %%
data = pd.concat([cognates_data, non_cognates_data])
data = shuffle(data)
data = data.reset_index(drop=True)
data.head()
# Out:
#      first_word    second_word  Levenshtein  longest_common_substr  \
# 0    Оргкомитет   Иеговистский            9                      1
# 1   Скопировать  Гробокопатель            8                      3
# 2  Керамзитовый      Несъёмный            9                      2
# 3  Варьирование     Ксеноновый           10                      2
# 4        Бывать       Диктовка            8                      1
#
#    longest_common_subs  class
# 0                    4      0
# 1                    6      1
# 2                    4      0
# 3                    2      0
# 4                    2      0

# %%
data = shuffle(data)
data.head()
# Out:
#            first_word   second_word  Levenshtein  longest_common_substr  \
# 1590     Кровососущий   Соплеменный           10                      1
# 955209       Затюкать      Досушить            6                      2
# 1062544      Метелить        Затечь            5                      2
# 607664       Калевать  Натравляться            8                      2
# 802046      Уваляться      Валивать            7                      2
#
#          longest_common_subs  class
# 1590                       2      0
# 955209                     2      0
# 1062544                    3      0
# 607664                     4      0
# 802046                     4      1

# %% [markdown]
# Добавим признаки:

# %%
data['Levenshtein_stemmed'] = data.apply(lambda row: levenshtein_distance(row.first_word, row.second_word), axis=1)
data.head()
# Out:
#            first_word   second_word  Levenshtein  longest_common_substr  \
# 1590     Кровососущий   Соплеменный           10                      1
# 955209       Затюкать      Досушить            6                      2
# 1062544      Метелить        Затечь            5                      2
# 607664       Калевать  Натравляться            8                      2
# 802046      Уваляться      Валивать            7                      2
#
#          longest_common_subs  class  Levenshtein_stemmed
# 1590                       2      0                    9
# 955209                     2      0                    6
# 1062544                    3      0                    3
# 607664                     4      0                    6
# 802046                     4      1                    4

# %%
data['LCS_stemmed'] = data.apply(lambda row: LCS(row.first_word, row.second_word), axis=1)
data.head()
# Out:
#            first_word   second_word  Levenshtein  longest_common_substr  \
# 1590     Кровососущий   Соплеменный           10                      1
# 955209       Затюкать      Досушить            6                      2
# 1062544      Метелить        Затечь            5                      2
# 607664       Калевать  Натравляться            8                      2
# 802046      Уваляться      Валивать            7                      2
#
#          longest_common_subs  class  Levenshtein_stemmed  LCS_stemmed
# 1590                       2      0                    9            2
# 955209                     2      0                    6            0
# 1062544                    3      0                    3            2
# 607664                     4      0                    6            1
# 802046                     4      1                    4            3

# %%
data['Levenshtein_similarity'] = data.apply(lambda row: levenshtein_similarity(row.first_word, row.second_word), axis=1)
data.head()
# Out:
#            first_word   second_word  Levenshtein  longest_common_substr  \
# 1590     Кровососущий   Соплеменный           10                      1
# 955209       Затюкать      Досушить            6                      2
# 1062544      Метелить        Затечь            5                      2
# 607664       Калевать  Натравляться            8                      2
# 802046      Уваляться      Валивать            7                      2
#
#          longest_common_subs  class  Levenshtein_stemmed  LCS_stemmed  \
# 1590                       2      0                    9            2
# 955209                     2      0                    6            0
# 1062544                    3      0                    3            2
# 607664                     4      0                    6            1
# 802046                     4      1                    4            3
#
#          Levenshtein_similarity
# 1590                   0.111111
# 955209                 0.166667
# 1062544                0.333333
# 607664                 0.166667
# 802046                 0.250000

# %%
data['before_lcs'] = data.apply(lambda row: before_lcs(row.first_word, row.second_word), axis=1)
data.head()
# Out:
#            first_word   second_word  Levenshtein  longest_common_substr  \
# 1590     Кровососущий   Соплеменный           10                      1
# 955209       Затюкать      Досушить            6                      2
# 1062544      Метелить        Затечь            5                      2
# 607664       Калевать  Натравляться            8                      2
# 802046      Уваляться      Валивать            7                      2
#
#          longest_common_subs  class  Levenshtein_stemmed  LCS_stemmed  \
# 1590                       2      0                    9            2
# 955209                     2      0                    6            0
# 1062544                    3      0                    3            2
# 607664                     4      0                    6            1
# 802046                     4      1                    4            3
#
#          Levenshtein_similarity  before_lcs
# 1590                   0.111111           6
# 955209                 0.166667           0
# 1062544                0.333333           0
# 607664                 0.166667           0
# 802046                 0.250000           2

# %%
data['after_lcs'] = data.apply(lambda row: after_lcs(row.first_word, row.second_word), axis=1)
data.head()
# Out:
#            first_word   second_word  Levenshtein  longest_common_substr  \
# 1590     Кровососущий   Соплеменный           10                      1
# 955209       Затюкать      Досушить            6                      2
# 1062544      Метелить        Затечь            5                      2
# 607664       Калевать  Натравляться            8                      2
# 802046      Уваляться      Валивать            7                      2
#
#          longest_common_subs  class  Levenshtein_stemmed  LCS_stemmed  \
# 1590                       2      0                    9            2
# 955209                     2      0                    6            0
# 1062544                    3      0                    3            2
# 607664                     4      0                    6            1
# 802046                     4      1                    4            3
#
#          Levenshtein_similarity  before_lcs  after_lcs
# 1590                   0.111111           6          5
# 955209                 0.166667           0          0
# 1062544                0.333333           0          2
# 607664                 0.166667           0          4
# 802046                 0.250000           2          1

# %%
data.to_csv('final_balanced_cognates_dataset.csv', encoding='cp1251')

# %% [markdown]
# # Построение модели

# %%
y = data['class']
X = data[['Levenshtein_stemmed', 'LCS_stemmed', 'Levenshtein_similarity', 'longest_common_subs', 'before_lcs', 'after_lcs']]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
X_train.head()
# Out:
#         Levenshtein_stemmed  LCS_stemmed  Levenshtein_similarity  \
# 74861                     8            2                0.125000
# 527053                   14            5                0.071429
# 250125                    3            6                0.333333
# 969827                   12            1                0.083333
# 205706                    5            7                0.200000
#
#         longest_common_subs  before_lcs  after_lcs
# 74861                     3           2          0
# 527053                    7           4          9
# 250125                    9           0          4
# 969827                    3           1          7
# 205706                    7           4          3

# %%
y_train.head()
# Out:
# 74861     0
# 527053    1
# 250125    1
# 969827    0
# 205706    1
# Name: class, dtype: int64

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import confusion_matrix  
from sklearn.metrics import accuracy_score

model = LGBMClassifier()
model.fit(X_train, y_train)

LGBM_prediction = model.predict(X_test)
print(accuracy_score(LGBM_prediction, y_test))
# Out:
# 0.9628801268336481

# %%
print(confusion_matrix(LGBM_prediction, y_test))
# Out:
# [[119429   4922]
#  [  4256 118646]]

# %%
import pickle

pickle.dump(model, open('clf_light_gbm.sav', 'wb'))

# %%
data.shape
# Out:
# (1236261, 11)
