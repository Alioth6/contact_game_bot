# %% [markdown]
# Сначала соберём словарь, состоящий из слов формального и неформального датасетов:

# %%
class WordTrie:
    '''
        How use 
        wt = WordTrie(FastText())
        wt.build_dict(['word', 'world', 'cat', 'cats'])
        for word, vector in wt.search_by_prefix('cats'): 
            print(word)
    '''
    def __init__(self, word2vec):
        self.root = _Node('*')
        self.get_vector = word2vec.get_vector
        self.model = word2vec

    def add(self, word, is_bigram=False):
        tmp_node = self.root

        for char in word:
            child = tmp_node.children.get(char, None)
            if child is None:
                child = _Node(char)
                tmp_node.children[char] = child
                child.parent = tmp_node
            tmp_node = child
        if not is_bigram and word in self.model.vocab:
            tmp_node.value = self.get_vector(word)
        tmp_node.freq += 1

    def build_dict(self, words):
        for word in words:
            self.add(word)
        return self

    def search_by_prefix(self, prefix):
        tmp_node = self.root

        for char in prefix:
            tmp_node = tmp_node.children.get(char, None)
            if tmp_node is None:
                return
        yield from tmp_node.get_childs()

# %%
class _Node:
    def __init__(self, char: str):
        self.char = char
        self.children = {}
        self.value = None
        self.parent = None
        self.freq = 0

    def _get_prefix(self):
        tmp_node = self
        prefix = ''
        while tmp_node.parent:
            prefix = tmp_node.char + prefix
            tmp_node = tmp_node.parent

        return prefix

    def get_childs(self):
        stack = [(self, self._get_prefix())]

        while stack:
            tmp_node, prefix = stack.pop(0)
            ##if tmp_node.value is not None:
            yield prefix, tmp_node.value, tmp_node.freq
            
            for char, child in tmp_node.children.items():
                stack.append((child, prefix+char))

# %%
import gensim

w2v_fpath = "all.norm-sz100-w10-cb0-it1-min100.w2v"
w2v_model = gensim.models.KeyedVectors.load_word2vec_format(w2v_fpath, binary=True, unicode_errors='ignore')
w2v_model.init_sims(replace=True)
for word, score in w2v_model.most_similar("дерево"):
    print(word, score)
# Out:
# дерево — 0.8678081035614014
# деревце 0.867724597454071
# деревцо 0.8552745580673218
# буковое 0.8502448797225952
# дерево, — 0.8466764688491821
# дерево… 0.8452415466308594
# срубленное 0.8443728685379028
# росшее 0.8330211639404297
# спиленное 0.826280951499939
# развесистое 0.8261986970901489

# %%
wt = WordTrie(w2v_model)

# %%
from string import punctuation
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import spacy

stops = stopwords.words("russian")

nlp = spacy.load('ru2')
nlp.add_pipe(nlp.create_pipe('sentencizer'), first=True)

def adding_new_words(dt):
    
    for sentence in dt['defs']:
        text = ''.join(x for x in sentence if x not in punctuation)
        words = word_tokenize(text, language="russian")
        words = [word for word in words if word not in stops]
        text = ' '.join(words)
        doc = nlp(text)
        words = [word.lemma_ for word in nlp(text)]
    
        for word in words:
            wt.add(word)
        
        for i in range(len(words) - 1):
            curr_bigram = words[i] + " " + words[i + 1]
            wt.add(curr_bigram, is_bigram=True)

# %%
import pandas as pd

file1 = 'test_set_002.csv'

data = pd.read_csv(file1, delimiter=',')

print(data.shape)
data.head(5)
# Out:
# (26861, 3)
#                                  defs          word  len
# 0                     колпак на лампе        абажур   15
# 1  настоятель католического монастыря         аббат   34
# 2              католический священник         аббат   22
# 3              католический монастырь     аббатство   22
# 4                слово из первых букв  аббревиатура   20

# %%
adding_new_words(data)

# %%
file2 = 'test_set_human_003.csv'

human_data = pd.read_csv(file2, comment='#')

print(human_data.shape)
human_data.head(5)
# Out:
# (962, 3)
#                            defs          word  len
# 0   легкое агрегатное состояние           газ   58
# 1  оскорбление самого значимого  святотатство   53
# 2       разновидность чего-либо           род   42
# 3        возвышенность наоборот        низина   20
# 4                скрученная еда         рулет   63

# %%
adding_new_words(human_data)

# %%
for word, vector, freq in wt.search_by_prefix('кот'): 
    print(word, freq)
# Out:
# кот 2
# кото 0
# котл 0
# котр 0
# котё 0
# коти 0
# кот  0
# коте 0
# котор 29
# котле 0
# котло 0
# котро 0
# котёл 10
# котир 0
# кот о 0
# котел 0
# которо 0
# которы 0
# котор  0
# котора 0
# котору 0
# котлет 0
# котлов 0
# котрог 0
# котёл  0
# котиро 0
# кот ос 0
# котель 0
# которое 96
# которой 257
# котором 182
# которог 0
# которых 68
# которые 55
# который 96
# которым 50
# котор к 0
# котор м 0
# котор д 0
# котор р 0
# котор п 0
# котор и 0
# котор э 0
# котор ч 0
# котор ц 0
# котор с 0
# котор ф 0
# котор о 0
# котор а 0
# котор б 0
# котор т 0
# которая 41
# которую 66
# котлета 5
# котлови 0
# котлова 0
# котрого 1
# котёл п 0
# котёл о 0
# котёл т 0
# котёл у 0
# котёл д 0
# котиров 0
# кот осо 0
# котельн 0
# которое  0
# которой  0
# котором  0
# которому 69
# которого 211
# которых  0
# которыхс 0
# которые  0
# который  0
# которым  0
# которыми 17
# котор ко 0
# котор кр 0
# котор ме 0
# котор мо 0
# котор де 0
# котор ра 0
# котор по 0
# котор пр 0
# котор па 0
# котор из 0
# котор иг 0
# котор эл 0
# котор че 0
# котор цв 0
# котор со 0
# котор са 0
# котор ст 0
# котор фи 0
# котор от 0
# котор ос 0
# котор ат 0
# котор ба 0
# котор те 0
# которая  0
# которую  0
# котлета  0
# котловин 0
# котлован 1
# котрого  0
# котёл пр 0
# котёл ос 0
# котёл тр 0
# котёл ус 0
# котёл дв 0
# котировк 0
# кот особ 0
# котельны 0
# которое п 0
# которое р 0
# которое в 0
# которое о 0
# которое с 0
# которое х 0
# которое н 0
# которое т 0
# которое к 0
# которое у 0
# которое б 0
# которое з 0
# которое г 0
# которое е 0
# которое д 0
# которое ф 0
# которое ч 0
# которое и 0
# которое я 0
# которое ц 0
# которое э 0
# которой в 0
# которой ч 0
# которой г 0
# которой н 0
# которой з 0
# которой р 0
# которой и 0
# которой о 0
# которой с 0
# которой у 0
# которой д 0
# которой к 0
# которой п 0
# которой т 0
# которой я 0
# которой м 0
# которой ф 0
# которой б 0
# которой е 0
# которой х 0
# которой а 0
# которой л 0
# которой ж 0
# которой ш 0
# котором п 0
# котором г 0
# котором о 0
# котором р 0
# котором у 0
# котором в 0
# котором ч 0
# котором т 0
# котором к 0
# котором и 0
# котором м 0
# котором с 0
# котором д 0
# котором н 0
# котором з 0
# котором ж 0
# котором а 0
# котором х 0
# котором л 0
# котором э 0
# котором ш 0
# котором ф 0
# которому  0
# которого  0
# которых ч 0
# которых м 0
# которых п 0
# которых у 0
# которых о 0
# которых с 0
# которых р 0
# которых и 0
# которых д 0
# которых ф 0
# которых я 0
# которых х 0
# которых а 0
# которых в 0
# которых н 0
# которых к 0
# которых л 0
# которых т 0
# которых э 0
# которых г 0
# которых ш 0
# которыхсу 0
# которые з 0
# которые м 0
# которые н 0
# которые р 0
# которые п 0
# которые б 0
# которые ч 0
# которые к 0
# которые с 0
# которые я 0
# которые в 0
# которые и 0
# которые ц 0
# которые у 0
# которые о 0
# которые г 0
# который п 0
# который с 0
# который н 0
# который р 0
# который в 0
# который у 0
# который о 0
# который к 0
# который з 0
# который ч 0
# который д 0
# который ж 0
# который г 0
# который и 0
# который т 0
# который ф 0
# которым б 0
# которым п 0
# которым в 0
# которым у 0
# которым н 0
# которым с 0
# которым д 0
# которым з 0
# которым г 0
# которым о 0
# которым х 0
# которым ч 0
# которым к 0
# которым р 0
# которыми  0
# котор кон 0
# котор кре 0
# котор мес 0
# котор моч 0
# котор дей 0
# котор рас 0
# котор раб 0
# котор под 0
# котор при 0
# котор пат 0
# котор изу 0
# котор игр 0
# котор эле 0
# котор чел 0
# котор цве 0
# котор соб 0
# котор сам 0
# котор стр 0
# котор фиг 0
# котор отп 0
# котор осн 0
# котор ато 0
# котор бал 0
# котор теч 0
# которая в 0
# которая у 0
# которая с 0
# которая з 0
# которая д 0
# которая о 0
# которая л 0
# которая п 0
# которая я 0
# которая и 0
# которая к 0
# которая р 0
# которая ц 0
# которая н 0
# которую н 0
# которую д 0
# которую с 0
# которую ч 0
# которую п 0
# которую в 0
# которую з 0
# которую к 0
# которую м 0
# которую о 0
# которую б 0
# которую т 0
# которую г 0
# которую у 0
# котлета р 0
# котловина 1
# котлован  0
# котрого с 0
# котёл про 0
# котёл осм 0
# котёл тру 0
# котёл уст 0
# котёл дви 0
# котировка 2
# кот особы 0
# котельный 1
# которое по 0
# которое пр 0
# которое пе 0
# которое ра 0
# которое вы 0
# которое ва 0
# которое во 0
# которое вл 0
# которое вз 0
# которое вх 0
# которое вв 0
# которое ор 0
# которое об 0
# которое ок 0
# которое ох 0
# которое ог 0
# которое со 0
# которое сл 0
# которое св 0
# которое ст 0
# которое са 0
# которое ск 0
# которое ха 0
# которое хо 0
# которое но 0
# которое ну 0
# которое на 0
# которое не 0
# которое то 0
# которое ти 0
# которое тя 0
# которое ко 0
# которое кр 0
# которое кт 0
# которое ум 0
# которое ус 0
# которое ун 0
# которое бу 0
# которое би 0
# которое за 0
# которое зе 0
# которое гл 0
# которое ед 0
# которое до 0
# которое де 0
# которое да 0
# которое фу 0
# которое чт 0
# которое ис 0
# которое из 0
# которое яв 0
# которое це 0
# которое эл 0
# которой вы 0
# которой вл 0
# которой вх 0
# которой ве 0
# которой во 0
# которой вн 0
# которой вр 0
# которой че 0
# которой ча 0
# которой чт 0
# которой чи 0
# которой го 0
# которой гр 0
# которой на 0
# которой ну 0
# которой не 0
# которой ни 0
# которой за 0
# которой зе 0
# которой ра 0
# которой ре 0
# которой из 0
# которой ис 0
# которой иг 0
# которой им 0
# которой об 0
# которой од 0
# которой оп 0
# которой ос 0
# которой ощ 0
# которой от 0
# которой он 0
# которой со 0
# которой сп 0
# которой су 0
# которой ст 0
# которой св 0
# которой сд 0
# которой см 0
# которой са 0
# которой ср 0
# которой си 0
# которой сх 0
# которой сл 0
# которой уч 0
# которой ум 0
# которой уд 0
# которой уз 0
# которой уп 0
# которой ук 0
# которой до 0
# которой дв 0
# которой де 0
# которой да 0
# которой ка 0
# которой кр 0
# которой кл 0
# которой ко 0
# которой кт 0
# которой по 0
# которой пр 0
# которой па 0
# которой пе 0
# которой пи 0
# которой пу 0
# которой те 0
# которой тр 0
# которой то 0
# которой яв 0
# которой мо 0
# которой му 0
# которой ма 0
# которой фо 0
# которой фе 0
# которой фу 0
# которой бо 0
# которой бе 0
# которой ез 0
# которой ха 0
# которой ар 0
# которой ле 0
# которой жи 0
# которой ши 0
# котором пр 0
# котором по 0
# котором пе 0
# котором па 0
# котором го 0
# котором гл 0
# котором од 0
# котором ос 0
# котором ощ 0
# котором ок 0
# котором об 0
# котором он 0
# котором оп 0
# котором от 0
# котором ре 0
# котором ра 0
# котором ру 0
# котором ус 0
# котором уч 0
# котором ук 0
# котором вы 0
# котором ва 0
# котором во 0
# котором вр 0
# котором ве 0
# котором вл 0
# котором ча 0
# котором че 0
# котором чи 0
# котором чу 0
# котором чт 0
# котором те 0
# котором та 0
# котором кр 0
# котором ки 0
# котором ка 0
# котором кт 0
# котором иг 0
# котором из 0
# котором ис 0
# котором им 0
# котором мо 0
# котором му 0
# котором ме 0
# котором ма 0
# котором со 0
# котором сп 0
# котором ст 0
# котором сх 0
# котором ск 0
# котором дв 0
# котором де 0
# котором на 0
# котором ни 0
# котором ну 0
# котором не 0
# котором но 0
# котором за 0
# котором зо 0
# котором жи 0
# котором аф 0
# котором ат 0
# котором ар 0
# котором хр 0
# котором ле 0
# котором ли 0
# котором лу 0
# котором ло 0
# котором эм 0
# котором ши 0
# котором ша 0
# котором фу 0
# которому п 0
# которому с 0
# которому т 0
# которому в 0
# которому р 0
# которому д 0
# которому о 0
# которому г 0
# которому ч 0
# которому к 0
# которому я 0
# которому у 0
# которому и 0
# которому б 0
# которому н 0
# которому м 0
# которого в 0
# которого о 0
# которого ч 0
# которого с 0
# которого н 0
# которого п 0
# которого и 0
# которого г 0
# которого р 0
# которого у 0
# которого я 0
# которого е 0
# которого л 0
# которого к 0
# которого х 0
# которого ш 0
# которого ф 0
# которого м 0
# которого ж 0
# которого д 0
# которого а 0
# которого ц 0
# которого з 0
# которого т 0
# которого б 0
# которых че 0
# которых чи 0
# которых чт 0
# которых му 0
# которых пе 0
# которых пр 0
# которых по 0
# которых ук 0
# которых от 0
# которых оп 0
# которых ос 0
# которых он 0
# которых со 0
# которых ск 0
# которых су 0
# которых ст 0
# которых ро 0
# которых ра 0
# которых из 0
# которых им 0
# которых ид 0
# которых до 0
# которых фо 0
# которых яв 0
# которых ха 0
# которых ав 0
# которых вх 0
# которых вн 0
# которых вы 0
# которых вв 0
# которых на 0
# которых не 0
# которых ни 0
# которых ко 0
# которых ли 0
# которых ле 0
# которых то 0
# которых эк 0
# которых ги 0
# которых шу 0
# которыхсуб 0
# которые за 0
# которые мо 0
# которые мн 0
# которые ну 0
# которые на 0
# которые не 0
# которые но 0
# которые ра 0
# которые ре 0
# которые по 0
# которые пр 0
# которые бо 0
# которые че 0
# которые чл 0
# которые ка 0
# которые сл 0
# которые яв 0
# которые вы 0
# которые во 0
# которые ве 0
# которые вл 0
# которые ис 0
# которые из 0
# которые им 0
# которые це 0
# которые ук 0
# которые ус 0
# которые од 0
# которые об 0
# которые оп 0
# которые га 0
# который пе 0
# который пр 0
# который пл 0
# который по 0
# который ст 0
# который сл 0
# который сч 0
# который сп 0
# который со 0
# который су 0
# который на 0
# который не 0
# который ра 0
# который ре 0
# который вы 0
# который вк 0
# который во 0
# который ве 0
# который вн 0
# который вм 0
# который ук 0
# который ух 0
# который уб 0
# который об 0
# который од 0
# который от 0
# который ок 0
# который оп 0
# который оч 0
# который кт 0
# который ка 0
# который ко 0
# который ку 0
# который за 0
# который ча 0
# который че 0
# который чт 0
# который де 0
# который до 0
# который да 0
# который жи 0
# который го 0
# который ис 0
# который им 0
# который тр 0
# который фе 0
# которым би 0
# которым бр 0
# которым пу 0
# которым пр 0
# которым по 0
# которым пе 0
# которым вы 0
# которым во 0
# которым ук 0
# которым уд 0
# которым ут 0
# которым уч 0
# которым на 0
# которым не 0
# которым со 0
# которым сн 0
# которым сл 0
# которым су 0
# которым са 0
# которым до 0
# которым ды 0
# которым за 0
# которым го 0
# которым ок 0
# которым хо 0
# которым чт 0
# которым ка 0
# которым ре 0
# которыми о 0
# которыми в 0
# которыми п 0
# которыми ч 0
# которыми с 0
# которыми к 0
# котор конц 0
# котор крес 0
# котор мест 0
# котор мочь 1
# котор дейс 0
# котор расп 0
# котор рабо 0
# котор подв 0
# котор прин 0
# котор патр 0
# котор изуч 0
# котор игро 0
# котор элем 0
# котор чело 0
# котор цвет 0
# котор собр 0
# котор само 0
# котор стру 0
# котор фигу 0
# котор отпе 0
# котор осно 0
# котор атом 2
# котор бале 0
# котор тече 0
# которая вы 0
# которая во 0
# которая вм 0
# которая ул 0
# которая уп 0
# которая уч 0
# которая уд 0
# которая сл 0
# которая со 0
# которая за 0
# которая до 0
# которая де 0
# которая ок 0
# которая об 0
# которая ле 0
# которая по 0
# которая пр 0
# которая яв 0
# которая ис 0
# которая кр 0
# которая ра 0
# которая ру 0
# которая це 0
# которая ни 0
# которая на 0
# которую но 0
# которую на 0
# которую ну 0
# которую не 0
# которую ду 0
# которую де 0
# которую др 0
# которую ст 0
# которую со 0
# которую сн 0
# которую сс 0
# которую сл 0
# которую са 0
# которую чт 0
# которую пр 0
# которую па 0
# которую по 0
# которую ве 0
# которую вс 0
# которую вк 0
# которую вх 0
# которую вы 0
# которую вд 0
# которую за 0
# которую кл 0
# которую ка 0
# которую ку 0
# которую кр 0
# которую ма 0
# которую мо 0
# которую оп 0
# которую он 0
# которую от 0
# которую од 0
# которую об 0
# которую ос 0
# которую бр 0
# которую тя 0
# которую тр 0
# которую га 0
# которую ув 0
# котлета ру 0
# котловина  0
# котловинам 0
# котлован з 0
# котрого ст 0
# котёл прои 0
# котёл осмо 0
# котёл труб 0
# котёл устр 0
# котёл двиг 0
# котировка  0
# кот особый 1
# котельный  0
# которое пог 0
# которое под 0
# которое про 0
# которое пре 0
# которое при 0
# которое пер 0
# которое раб 0
# которое вып 0
# которое выр 0
# которое выз 0
# которое выс 0
# которое вар 0
# которое воз 0
# которое вле 0
# которое взя 0
# которое вхо 0
# которое вве 0
# которое орг 0
# которое обе 0
# которое обр 0
# которое обл 0
# которое оки 0
# которое охв 0
# которое охо 0
# которое огр 0
# которое соо 0
# которое соб 0
# которое сос 0
# которое соп 0
# которое сод 0
# которое сое 0
# которое слу 0
# которое свя 0
# которое ста 0
# которое сам 0
# которое скл 0
# которое хар 0
# которое хот 0
# которое нос 0
# которое нуж 0
# которое нас 0
# которое нео 0
# которое нев 0
# которое тол 0
# которое тип 0
# которое тян 0
# которое кон 0
# которое ком 0
# которое кре 0
# которое кто 0
# которое уме 0
# которое уст 0
# которое уно 0
# которое буд 0
# которое бит 0
# которое зав 0
# которое зап 0
# которое зан 0
# которое зем 0
# которое гла 0
# которое еди 0
# которое дол 0
# которое дои 0
# которое дей 0
# которое дел 0
# которое дав 0
# которое фун 0
# которое что 0
# которое исп 0
# которое изм 0
# которое явл 0
# которое цел 0
# которое эле 0
# которой выз 0
# которой вып 0
# которой выс 0
# которой выр 0
# которой выи 0
# которой вла 0
# которой вхо 0
# которой вещ 0
# которой вер 0
# которой вол 0
# которой вос 0
# которой вне 0
# которой вра 0
# которой чер 0
# которой чел 0
# которой час 0
# которой что 0
# которой чит 0
# которой гос 0
# которой гон 0
# которой гра 0
# которой нах 0
# которой нач 0
# которой наз 0
# которой нар 0
# которой нав 0
# которой нуж 0
# которой нео 0
# которой ниж 0
# которой зав 0
# которой зар 0
# которой зам 0
# которой зак 0
# которой зан 0
# которой зад 0
# которой заг 0
# которой зап 0
# которой зем 0
# которой рас 0
# которой раз 0
# которой раб 0
# которой рав 0
# которой рег 0
# которой рез 0
# которой изм 0
# которой изг 0
# которой изо 0
# которой исп 0
# которой исч 0
# которой исх 0
# которой игр 0
# которой ими 0
# которой име 0
# которой обл 0
# которой обы 0
# которой объ 0
# которой обр 0
# которой обу 0
# которой одн 0
# которой оди 0
# которой оде 0
# которой опы 0
# которой осн 0
# которой ост 0
# которой ощу 0
# которой отк 0
# которой отд 0
# которой оно 2
# которой соз 0
# которой сов 0
# которой сос 0
# которой соо 0
# которой сод 0
# которой сое 0
# которой сог 0
# которой спе 0
# которой спи 0
# которой спу 0
# которой сущ 0
# которой суп 1
# которой сто 0
# которой стя 0
# которой стр 0
# которой свя 0
# которой све 0
# которой сде 0
# которой сма 0
# которой сал 0
# которой сам 0
# которой сре 0
# которой сид 0
# которой схо 0
# которой сло 0
# которой уча 0
# которой уме 0
# которой уда 0
# которой удо 0
# которой узн 0
# которой упл 0
# которой упр 0
# которой ука 0
# которой укр 0
# которой дор 0
# которой дол 0
# которой дви 0
# которой дей 0
# которой дел 0
# которой дал 0
# которой дан 0
# которой каж 0
# которой кре 0
# которой клю 0
# которой коч 0
# которой кор 0
# которой кож 0
# которой ком 0
# которой кто 0
# которой пол 0
# которой поз 0
# которой под 0
# которой пом 0
# которой пон 0
# которой пок 0
# которой про 0
# которой при 0
# которой пре 0
# которой пря 0
# которой пад 0
# которой пар 0
# которой пер 0
# которой пиш 0
# которой пит 0
# которой пуг 0
# которой тел 0
# которой тре 0
# которой тра 0
# которой тов 0
# которой явл 0
# которой мол 0
# которой муэ 0
# которой мат 0
# которой фор 0
# которой фес 0
# которой фун 0
# которой бол 0
# которой бес 0
# которой езд 0
# которой хар 0
# которой арг 0
# которой леж 0
# которой жил 0
# которой жит 0
# которой шит 0
# котором про 0
# котором пра 0
# котором при 0
# котором пре 0
# котором под 0
# котором пол 0
# котором пох 0
# котором пос 0
# котором пов 0
# котором пер 0
# котором пар 0
# котором гот 0
# котором гов 0
# котором гла 0
# котором оди 0
# котором одн 0
# котором осн 0
# котором осу 0
# котором ощу 0
# котором ока 0
# котором обо 0
# котором обн 0
# котором обы 0
# котором обе 0
# котором оно 1
# котором опр 0
# котором отд 0
# котором рез 0
# котором рег 0
# котором раб 0
# котором раз 0
# котором рас 0
# котором рук 0
# котором уст 0
# котором уча 0
# котором укр 0
# котором выр 0
# котором вып 0
# котором вар 0
# котором воз 0
# котором вра 0
# котором вещ 0
# котором вла 0
# котором час 0
# котором чел 0
# котором чес 0
# котором чис 0
# котором чув 0
# котором что 0
# котором тел 0
# котором тер 0
# котором тан 0
# котором кре 0
# котором кис 0
# котором кач 0
# котором каж 0
# котором кто 0
# котором игр 0
# котором изу 0
# котором изо 0
# котором изл 0
# котором изг 0
# котором изз 0
# котором исп 0
# котором имм 0
# котором мол 0
# котором муз 0
# котором мел 0
# котором мас 0
# котором сос 0
# котором сов 0
# котором сод 0
# котором соб 0
# котором соп 0
# котором сох 0
# котором спо 0
# котором сто 0
# котором ста 0
# котором стр 0
# котором схе 0
# котором ска 0
# котором два 1
# котором дер 0
# котором нар 0
# котором нах 0
# котором нав 0
# котором нап 0
# котором ник 0
# котором нуж 0
# котором неп 0
# котором нео 0
# котором неэ 0
# котором нос 0
# котором зап 0
# котором зас 0
# котором зад 0
# котором зав 0
# котором зол 0
# котором жиз 0
# котором жид 0
# котором афф 0
# котором ато 0
# котором арт 0
# котором хра 0
# котором леж 0
# котором лиз 0
# котором лид 0
# котором лун 0
# котором лош 0
# котором эмо 0
# котором шир 0
# котором шар 1
# котором фун 0
# которому пе 0
# которому пр 0
# которому по 0
# которому св 0
# которому ст 0
# которому сд 0
# которому сл 0
# которому ск 0
# которому съ 0
# которому тр 0
# которому те 0
# которому та 0
# которому въ 0
# которому вы 0
# которому ре 0
# которому ра 0
# которому до 0
# которому дв 0
# которому де 0
# которому ос 0
# которому об 0
# которому от 0
# которому га 0
# которому чт 0
# которому че 0
# которому ко 0
# которому кр 0
# которому яс 0
# которому уз 0
# которому из 0
# которому бл 0
# которому на 0
# которому мо 0
# которого вы 0
# которого во 0
# которого вл 0
# которого вп 0
# которого вх 0
# которого оп 0
# которого од 0
# которого он 0
# которого об 0
# которого ох 0
# которого ос 0
# которого ог 0
# которого ощ 0
# которого от 0
# которого чи 0
# которого че 0
# которого чт 0
# которого со 0
# которого су 0
# которого сн 0
# которого ст 0
# которого сч 0
# которого сл 0
# которого св 0
# которого сп 0
# которого см 0
# которого на 0
# которого не 0
# которого но 0
# которого по 0
# которого пр 0
# которого пе 0
# которого па 0
# которого пи 0
# которого им 0
# которого ис 0
# которого из 0
# которого ид 0
# которого го 0
# которого ра 0
# которого ум 0
# которого уп 0
# которого уч 0
# которого яв 0
# которого як 0
# которого ес 0
# которого ле 0
# которого ли 0
# которого ло 0
# которого лю 0
# которого ко 0
# которого кт 0
# которого ха 0
# которого ша 0
# которого фр 0
# которого мо 0
# которого ме 0
# которого же 0
# которого де 0
# которого до 0
# которого дв 0
# которого ар 0
# которого ци 0
# которого за 0
# которого то 0
# которого бл 0
# которых чел 0
# которых чис 0
# которых что 0
# которых муч 0
# которых печ 0
# которых пер 0
# которых про 0
# которых пре 0
# которых поп 0
# которых поз 0
# которых укр 0
# которых отс 0
# которых отр 0
# которых опр 0
# которых осу 0
# которых осн 0
# которых оно 1
# которых сос 0
# которых сор 0
# которых сод 0
# которых скр 0
# которых скл 0
# которых суб 0
# которых ста 0
# которых род 0
# которых рас 0
# которых изо 0
# которых изв 0
# которых име 0
# которых идт 0
# которых доч 0
# которых фор 0
# которых явл 0
# которых хар 0
# которых авт 0
# которых вхо 0
# которых вне 0
# которых выс 0
# которых вве 0
# которых наб 0
# которых нес 0
# которых нем 0
# которых низ 0
# которых кон 0
# которых лиш 0
# которых леж 0
# которых тот 1
# которых экр 0
# которых гид 0
# которых шум 1
# которыхсубъ 0
# которые зад 0
# которые зач 0
# которые моч 0
# которые мне 0
# которые нуж 0
# которые над 0
# которые нап 0
# которые нек 0
# которые нор 0
# которые рас 0
# которые раз 0
# которые рег 0
# которые поп 0
# которые пол 0
# которые поз 0
# которые под 0
# которые при 0
# которые пре 0
# которые бол 0
# которые чел 0
# которые чле 0
# которые кас 0
# которые сли 0
# которые слу 0
# которые явл 0
# которые выб 0
# которые воз 0
# которые веш 0
# которые вла 0
# которые исп 0
# которые изв 0
# которые име 0
# которые цен 0
# которые ука 0
# которые усл 0
# которые одн 0
# которые обы 0
# которые опр 0
# которые гар 0
# который пер 0
# который про 0
# который при 0
# который пре 0
# который пра 0
# который пла 0
# который пос 0
# который под 0
# который пол 0
# который поз 0
# который сто 0
# который сле 0
# который слу 0
# который счи 0
# который спе 0
# который спр 0
# который сор 0
# который соз 0
# который суе 0
# который нам 0
# который нав 0
# который нах 0
# который нан 0
# который нак 0
# который нат 0
# который нап 0
# который нео 0
# который нев 0
# который раз 0
# который раб 0
# который рел 0
# который реш 0
# который выд 0
# который выр 0
# который вкл 0
# который воз 0
# который вос 0
# который вод 0
# который вол 0
# который вер 0
# который вно 0
# который вме 0
# который ука 0
# который уха 0
# который уби 0
# который обы 0
# который оба 1
# который оди 0
# который отр 0
# который ока 0
# который опр 0
# который опу 0
# который очи 0
# который кто 0
# который кан 0
# который кол 0
# который кур 0
# который зав 0
# который заж 0
# который зар 0
# который зах 0
# который час 0
# который чел 0
# который что 0
# который дел 0
# который дер 0
# который доб 0
# который дав 0
# который жиз 0
# который гот 0
# который гов 0
# который исп 0
# который име 0
# который тре 0
# который фет 0
# которым бит 0
# которым бро 0
# которым пуг 0
# которым про 0
# которым при 0
# которым пок 0
# которым пер 0
# которым выз 0
# которым вос 0
# которым укр 0
# которым удо 0
# которым утв 0
# которым уча 0
# которым нар 0
# которым нап 0
# которым нах 0
# которым нак 0
# которым нео 0
# которым сос 0
# которым соо 0
# которым сна 0
# которым слу 0
# которым сущ 0
# которым сат 0
# которым дос 0
# которым дол 0
# которым дыш 0
# которым заж 0
# которым зап 0
# которым заб 0
# которым гот 0
# которым окл 0
# которым хол 0
# которым что 0
# которым как 0
# которым рег 0
# которыми об 0
# которыми ос 0
# которыми вы 0
# которыми вс 0
# которыми пр 0
# которыми по 0
# которыми чт 0
# которыми со 0
# которыми св 0
# которыми кт 0
# котор конце 0
# котор крест 0
# котор место 1
# котор дейст 0
# котор распр 0
# котор рабоч 0
# котор подве 0
# котор прино 0
# котор патро 0
# котор изуча 0
# котор игрок 1
# котор элеме 0
# котор челов 0
# котор цвето 0
# котор собра 0
# котор самол 0
# котор струн 0
# котор фигур 0
# котор отпеч 0
# котор основ 0
# котор балер 0
# котор течен 0
# которая выр 0
# которая выч 0
# которая воз 0
# которая вме 0
# которая улу 0
# которая упи 0
# которая уча 0
# которая уда 0
# которая слу 0
# которая соо 0
# которая сов 0
# которая сод 0
# которая зан 0
# которая зам 0
# которая дои 0
# которая дол 0
# которая дел 0
# которая дер 0
# которая ока 0
# которая обе 0
# которая общ 0
# которая леч 0
# которая под 0
# которая пон 0
# которая пос 0
# которая пов 0
# которая пре 0
# которая явл 0
# которая исп 0
# которая кре 0
# которая раз 0
# которая рас 0
# которая рук 0
# которая цел 0
# которая ниж 0
# которая нат 0
# которую нос 0
# которую нат 0
# которую над 0
# которую нуж 0
# которую нев 0
# которую дуэ 0
# которую дел 0
# которую дер 0
# которую дру 0
# которую ста 0
# которую стр 0
# которую соб 0
# которую сни 0
# которую ссс 0
# которую сле 0
# которую сад 0
# которую что 0
# которую при 0
# которую про 0
# которую пад 0
# которую пов 0
# которую пом 0
# которую пол 0
# которую веш 0
# которую век 0
# которую вст 0
# которую вкл 0
# которую вхо 0
# которую выд 0
# которую вде 0
# которую зат 0
# которую зад 0
# которую кла 0
# которую кач 0
# которую кук 0
# которую кре 0
# которую мат 0
# которую моч 0
# которую опу 0
# которую оно 1
# которую отл 0
# которую оди 0
# которую обр 0
# которую ост 0
# которую бра 0
# которую тян 0
# которую тру 0
# которую гар 0
# которую уве 0
# котлета руб 0
# котловина п 0
# котловинами 1
# котлован за 0
# котрого сто 0
# котёл произ 0
# котёл осмот 0
# котёл труба 1
# котёл устро 0
# котёл двига 0
# котировка а 0
# котировка ф 0
# котельный у 0
# которое погл 0
# которое подл 0
# которое прох 0
# которое прое 0
# которое прой 0
# которое прон 0
# которое прои 0
# которое прео 0
# которое пред 0
# которое прив 0
# которое пере 0
# которое рабо 0
# которое выпи 0
# которое выпу 0
# которое выра 0
# которое вызы 0
# которое выст 0
# которое вари 0
# которое возн 0
# которое влет 0
# которое взят 0
# которое вход 0
# которое ввез 0
# которое орга 0
# которое обес 0
# которое обра 0
# которое обла 0
# которое окин 0
# которое охва 0
# которое охот 0
# которое огра 0
# которое сооб 0
# которое соби 0
# которое сост 0
# которое сопо 0
# которое соде 0
# которое соед 0
# которое случ 0
# которое служ 0
# которое связ 0
# которое став 0
# которое само 1
# которое скла 0
# которое хара 0
# которое хотя 1
# которое носи 0
# которое нужн 0
# которое наст 0
# которое необ 0
# которое нево 0
# которое толк 0
# которое типи 0
# которое тяну 0
# которое конк 0
# которое комм 0
# которое креп 0
# которое ктол 0
# которое умен 0
# которое уста 0
# которое унос 0
# которое буду 0
# которое бить 1
# которое заве 0
# которое запи 0
# которое зани 0
# которое земл 0
# которое глаз 1
# которое един 0
# которое долж 0
# которое доит 0
# которое дейс 0
# которое дела 0
# которое дава 0
# которое функ 0
# которое чтол 0
# которое испо 0
# которое изме 0
# которое явля 0
# которое целы 0
# которое элем 0
# которой вызв 0
# которой выпе 0
# которой выст 0
# которой высо 0
# которой выра 0
# которой выиг 0
# которой влас 0
# которой вход 0
# которой веще 0
# которой верт 0
# которой верх 0
# которой воло 0
# которой восп 0
# которой внеш 0
# которой вращ 0
# которой черн 0
# которой чело 0
# которой част 0
# которой чтол 0
# которой чита 0
# которой гост 0
# которой гонщ 0
# которой грав 0
# которой нахо 0
# которой начи 0
# которой назв 0
# которой наря 0
# которой наве 0
# которой нужн 0
# которой необ 0
# которой ниже 0
# которой зави 0
# которой зару 0
# которой заме 0
# которой зака 0
# которой закр 0
# которой закл 0
# которой зани 0
# которой зада 0
# которой заго 0
# которой загн 0
# которой заги 0
# которой запа 0
# которой земл 0
# которой расс 0
# которой расп 0
# которой разм 0
# которой разд 0
# которой разр 0
# которой рабо 0
# которой равн 0
# которой регу 0
# которой резу 0
# которой изме 0
# которой изго 0
# которой изоб 0
# которой испо 0
# которой исчи 0
# которой исхо 0
# которой игра 0
# которой игро 0
# которой имит 0
# которой имет 0
# которой обла 0
# которой обыч 0
# которой объе 0
# которой обра 0
# которой обус 0
# которой одна 1
# которой одно 1
# которой один 0
# которой одев 0
# которой опыл 0
# которой осно 0
# которой оста 0
# которой ощущ 0
# которой отку 0
# которой отде 0
# которой созн 0
# которой созд 0
# которой созр 0
# которой совп 0
# которой сове 0
# которой сост 0
# которой соот 0
# которой соде 0
# которой соед 0
# которой согл 0
# которой спер 0
# которой спил 0
# которой спус 0
# которой суще 0
# которой стоя 0
# которой стяг 0
# которой стру 0
# которой связ 0
# которой свет 0
# которой сдел 0
# которой смач 0
# которой саля 0
# которой само 0
# которой сами 1
# которой срез 0
# которой сиде 0
# которой сход 0
# которой слов 0
# которой учас 0
# которой умер 0
# которой удар 0
# которой удов 0
# которой узна 0
# которой упла 0
# которой упра 0
# которой указ 0
# которой укре 0
# которой доро 0
# которой долж 0
# которой движ 0
# которой двиг 0
# которой дейс 0
# которой дела 0
# которой даль 0
# которой данн 0
# которой кажд 0
# которой креп 0
# которой клюш 0
# которой коче 0
# которой коро 0
# которой кожа 1
# которой комп 0
# которой ктол 0
# которой полы 0
# которой поло 0
# которой поли 0
# которой позв 0
# которой позн 0
# которой пода 0
# которой поме 0
# которой поня 0
# которой поне 0
# которой покр 0
# которой прои 0
# которой прос 0
# которой прод 0
# которой пров 0
# которой прох 0
# которой прив 0
# которой прин 0
# которой прик 0
# которой прих 0
# которой прим 0
# которой прис 0
# которой прек 0
# которой пред 0
# которой прят 0
# которой пада 0
# которой пари 0
# которой пере 0
# которой пише 0
# которой пита 0
# которой пуга 0
# которой тело 4
# которой тела 0
# которой треб 0
# которой трат 0
# которой това 0
# которой явля 0
# которой моло 0
# которой муэд 0
# которой мате 0
# которой форм 0
# которой фест 0
# которой функ 0
# которой боль 0
# которой беск 0
# которой езди 0
# которой хара 0
# которой аргу 0
# которой лежа 0
# которой жило 0
# которой жить 1
# которой шить 1
# котором прох 0
# котором прои 0
# котором прой 0
# котором прод 0
# котором прав 0
# котором приг 0
# котором приб 0
# котором пред 0
# котором пода 0
# котором подг 0
# котором подд 0
# котором поло 0
# котором похо 0
# котором пост 0
# котором пове 0
# котором перв 0
# котором пере 0
# котором пари 0
# котором гото 0
# котором гово 0
# котором глав 0
# котором глаз 1
# котором один 1
# котором одно 2
# котором осно 0
# котором осущ 0
# котором ощущ 0
# котором оказ 0
# котором обоз 0
# котором обна 0
# котором обыч 0
# котором обес 0
# котором опре 0
# котором отде 0
# котором резк 0
# котором реги 0
# котором рабо 0
# котором разл 0
# котором разв 0
# котором разъ 0
# котором расп 0
# котором расс 0
# котором рука 1
# котором уста 0
# котором учас 0
# котором укре 0
# котором выра 0
# котором выпо 0
# котором варя 0
# котором возд 0
# котором возм 0
# котором вращ 0
# котором врат 0
# котором веще 0
# котором влас 0
# котором част 0
# котором чело 0
# котором чест 0
# котором числ 0
# котором чувс 0
# котором чтол 0
# котором тело 3
# котором теря 0
# котором танц 0
# котором креп 0
# котором кист 0
# котором каче 0
# котором кача 0
# котором кажд 0
# котором ктол 0
# котором игро 0
# котором игра 0
# котором изуч 0
# котором изоб 0
# котором изло 0
# котором изго 0
# котором изза 1
# котором испо 0
# котором имму 0
# котором моле 0
# котором музы 0
# котором мелк 0
# котором маск 0
# котором сост 0
# котором соср 0
# котором совп 0
# котором сове 0
# котором соде 0
# котором соби 0
# котором сопр 0
# котором сохр 0
# котором спос 0
# котором стоп 0
# котором став 0
# котором стре 0
# котором схем 0
# котором скал 0
# котором держ 0
# котором нару 0
# котором наря 0
# котором нахо 0
# котором наве 0
# котором напи 0
# котором никт 0
# котором нужн 0
# котором непр 0
# котором неог 0
# котором неэл 0
# котором носи 0
# котором запр 0
# котором засл 0
# котором зада 0
# котором зави 0
# котором золя 0
# котором жизн 0
# котором жидк 0
# котором аффи 0
# котором атом 1
# котором арти 0
# котором хран 0
# котором лежа 0
# котором лизи 0
# котором лиди 0
# котором луна 1
# котором лоша 0
# котором эмоц 0
# котором широ 0
# котором функ 0
# которому пер 0
# которому про 0
# которому пре 0
# которому пра 0
# которому при 0
# которому пор 0
# которому пов 0
# которому под 0
# которому сво 0
# которому стр 0
# которому сте 0
# которому ста 0
# которому сде 0
# которому сле 0
# которому ско 0
# которому съе 0
# которому тру 0
# которому теч 0
# которому так 0
# которому въе 0
# которому выг 0
# которому рек 0
# которому раз 0
# которому дол 0
# которому дви 0
# которому дел 0
# которому осу 0
# которому обо 0
# которому объ 0
# которому отр 0
# которому гад 0
# которому что 0
# которому чел 0
# которому кот 0
# которому ком 0
# которому кре 0
# которому ясн 0
# которому узн 0
# которому изм 0
# которому изг 0
# которому бло 0
# которому нан 0
# которому мор 0
# которого вып 0
# которого вых 0
# которого вод 0
# которого вос 0
# которого вли 0
# которого впр 0
# которого вхо 0
# которого опр 0
# которого опи 0
# которого одн 0
# которого оно 2
# которого обр 0
# которого объ 0
# которого охл 0
# которого осо 0
# которого осн 0
# которого осу 0
# которого огр 0
# которого ощу 0
# которого отр 0
# которого отл 0
# которого чих 0
# которого чит 0
# которого чет 0
# которого чер 0
# которого что 0
# которого сод 0
# которого сов 0
# которого сос 0
# которого сое 0
# которого сог 0
# которого сок 0
# которого суд 0
# которого суб 0
# которого сни 0
# которого стр 0
# которого сто 0
# которого счи 0
# которого сло 0
# которого свя 0
# которого спо 0
# которого сме 0
# которого нар 0
# которого наб 0
# которого нап 0
# которого нах 0
# которого наз 0
# которого нан 0
# которого нам 0
# которого нас 0
# которого нач 0
# которого нео 0
# которого неп 0
# которого нес 0
# которого нос 0
# которого пос 0
# которого под 0
# которого пог 0
# которого пол 0
# которого пом 0
# которого пок 0
# которого пох 0
# которого при 0
# которого пре 0
# которого про 0
# которого пря 0
# которого пер 0
# которого пес 0
# которого пар 0
# которого пик 1
# которого име 0
# которого исп 0
# которого исч 0
# которого изо 0
# которого идт 0
# которого гот 0
# которого раз 0
# которого рав 0
# которого уме 0
# которого упо 0
# которого уча 0
# которого явл 0
# которого яко 0
# которого ест 0
# которого леч 0
# которого лет 0
# которого леж 0
# которого лиц 0
# которого лош 0
# которого люб 0
# которого кот 0
# которого ком 0
# которого кто 0
# которого хар 0
# которого шам 0
# которого фро 0
# которого моч 0
# которого мен 0
# которого жен 0
# которого дел 0
# которого дол 0
# которого два 1
# которого арм 0
# которого цик 0
# которого защ 0
# которого заш 0
# которого точ 0
# которого бла 0
# которых чело 0
# которых числ 0
# которых чтол 0
# которых мучи 0
# которых печа 0
# которых пере 0
# которых прох 0
# которых прои 0
# которых пред 0
# которых попе 0
# которых позв 0
# которых укре 0
# которых отсу 0
# которых отри 0
# которых опре 0
# которых осущ 0
# которых осно 0
# которых сост 0
# которых соре 0
# которых соде 0
# которых скры 0
# которых скла 0
# которых субъ 0
# которых стар 0
# которых роди 0
# которых раск 0
# которых изол 0
# которых извл 0
# которых имет 0
# которых идти 1
# которых доче 0
# которых форм 0
# которых явля 0
# которых хара 0
# которых авто 0
# которых вход 0
# которых внеш 0
# которых выст 0
# которых ввес 0
# которых набл 0
# которых наби 0
# которых несп 0
# которых неми 0
# которых низк 0
# которых коне 0
# которых лиша 0
# которых лежа 0
# которых экра 0
# которых гидр 0
# которыхсубъе 0
# которые зада 0
# которые зача 0
# которые мочь 5
# которые мнен 0
# которые нужн 0
# которые наде 0
# которые напо 0
# которые неко 0
# которые норм 0
# которые расп 0
# которые разб 0
# которые разл 0
# которые регу 0
# которые попа 0
# которые поль 0
# которые позв 0
# которые подн 0
# которые прин 0
# которые прик 0
# которые пред 0
# которые боль 0
# которые боле 0
# которые чело 0
# которые член 0
# которые каса 0
# которые слив 0
# которые случ 0
# которые явля 0
# которые выби 0
# которые возл 0
# которые веша 0
# которые влад 0
# которые испо 0
# которые изве 0
# которые имет 0
# которые цент 0
# которые указ 0
# которые усло 0
# которые одно 0
# которые обыч 0
# которые опре 0
# которые гара 0
# который пере 0
# который прои 0
# который прод 0
# который прин 0
# который прив 0
# который пред 0
# который прео 0
# который прав 0
# который плат 0
# который пост 0
# который подж 0
# который полу 0
# который позв 0
# который стоя 0
# который след 0
# который служ 0
# который счит 0
# который спец 0
# который спро 0
# который сорт 0
# который созд 0
# который суев 0
# который нама 0
# который наве 0
# который нахо 0
# который нано 0
# который нане 0
# который накл 0
# который натя 0
# который напи 0
# который необ 0
# который нево 0
# который разм 0
# который рабо 0
# который рели 0
# который реша 0
# который выде 0
# который выра 0
# который вкла 0
# который возг 0
# который восп 0
# который води 0
# который воло 0
# который вери 0
# который внос 0
# который вмес 0
# который указ 0
# который ухаж 0
# который убир 0
# который обыч 0
# который один 1
# который отри 0
# который оказ 0
# который опре 0
# который опус 0
# который очищ 0
# который ктол 0
# который кана 0
# который коло 0
# который куря 0
# который заве 0
# который зави 0
# который зажи 0
# который заря 0
# который захв 0
# который част 0
# который чело 0
# который чтол 0
# который дела 0
# который держ 0
# который доба 0
# который дава 0
# который жизн 0
# который гото 0
# который гово 0
# который испо 0
# который имет 0
# который треб 0
# который фети 0
# которым бить 2
# которым брос 0
# которым пуга 0
# которым прои 0
# которым прот 0
# которым прим 0
# которым прис 0
# которым прич 0
# которым прив 0
# которым покр 0
# которым пере 0
# которым вызы 0
# которым вост 0
# которым укра 0
# которым укры 0
# которым удов 0
# которым утве 0
# которым учащ 0
# которым наро 0
# которым напо 0
# которым нахо 0
# которым накр 0
# которым необ 0
# которым сост 0
# которым соот 0
# которым снар 0
# которым служ 0
# которым суще 0
# которым сата 0
# которым дост 0
# которым долж 0
# которым дыша 0
# которым зажи 0
# которым запо 0
# которым заби 0
# которым гото 0
# которым окли 0
# которым холо 0
# которым чтол 0
# которым кака 0
# которым регу 0
# которыми обе 0
# которыми обы 0
# которыми осы 0
# которыми осн 0
# которыми выс 0
# которыми вст 0
# которыми про 0
# которыми пок 0
# которыми пол 0
# которыми что 0
# которыми сое 0
# которыми свя 0
# которыми кто 0
# котор концен 0
# котор кресть 0
# котор действ 0
# котор распро 0
# котор рабочи 0
# котор подвес 0
# котор принос 0
# котор патрон 1
# котор изучат 0
# котор элемен 0
# котор челове 0
# котор цветон 0
# котор цветок 1
# котор собрат 0
# котор самолё 0
# котор струна 2
# котор фигурн 0
# котор отпеча 0
# котор основа 1
# котор балери 0
# котор течени 0
# которая выра 0
# которая вычи 0
# которая возн 0
# которая вмес 0
# которая улуч 0
# которая упир 0
# которая учас 0
# которая удар 0
# которая служ 0
# которая соот 0
# которая сове 0
# которая соде 0
# которая зани 0
# которая заме 0
# которая доит 0
# которая долж 0
# которая дела 0
# которая держ 0
# которая окай 0
# которая обес 0
# которая общи 0
# которая лечь 1
# которая подо 0
# которая подд 0
# которая пони 0
# которая пост 0
# которая повт 0
# которая прел 0
# которая явля 0
# которая испы 0
# которая креп 0
# которая разв 0
# которая расс 0
# которая расп 0
# которая руко 0
# которая цели 0
# которая нижн 0
# которая натя 0
# которую носи 0
# которую натя 0
# которую наде 0
# которую нужн 0
# которую нево 0
# которую дуэл 0
# которую дели 0
# которую дела 0
# которую держ 0
# которую друг 0
# которую став 0
# которую стре 0
# которую соби 0
# которую сниж 0
# которую ссср 1
# которую след 0
# которую сади 0
# которую чтол 0
# которую прих 0
# которую прох 0
# которую прод 0
# которую прои 0
# которую пада 0
# которую повы 0
# которую поме 0
# которую поль 0
# которую веша 0
# которую векс 0
# которую вста 0
# которую вкла 0
# которую вход 0
# которую выда 0
# которую вдел 0
# которую затр 0
# которую зада 0
# которую клас 0
# которую каче 0
# которую кукл 0
# которую креп 0
# которую мате 0
# которую мочь 1
# которую опус 0
# которую отли 0
# которую один 1
# которую обра 0
# которую оста 0
# которую брат 0
# которую тяну 0
# которую труд 0
# которую гара 0
# которую увел 0
# котлета рубл 0
# котловина по 0
# котловинами  0
# котлован зак 0
# котрого стоя 0
# котёл произв 0
# котёл осмотр 1
# котёл устрой 0
# котёл двигат 0
# котировка ак 0
# котировка фи 0
# котельный ус 0
# которое погло 0
# которое подле 0
# которое прохо 0
# которое проец 0
# которое проез 0
# которое пройт 0
# которое прони 0
# которое проис 0
# которое преод 0
# которое предн 0
# которое приве 0
# которое приви 0
# которое перех 0
# которое перед 0
# которое работ 0
# которое выпис 0
# которое выпус 0
# которое выраж 0
# которое вызыв 0
# которое выста 0
# которое варит 0
# которое возни 0
# которое влета 0
# которое взять 3
# которое входи 0
# которое ввезт 0
# которое орган 0
# которое обесп 0
# которое образ 0
# которое облад 0
# которое окину 0
# которое охват 0
# которое охоти 0
# которое ограж 0
# которое сообщ 0
# которое собир 0
# которое состо 0
# которое сопос 0
# которое содер 0
# которое соеди 0
# которое случа 0
# которое служи 0
# которое связа 0
# которое стави 0
# которое склад 0
# которое харак 0
# которое носит 0
# которое нужны 0
# которое насто 0
# которое насту 0
# которое необх 0
# которое невоз 0
# которое толко 0
# которое типич 0
# которое тянут 0
# которое конку 0
# которое комме 0
# которое крепи 0
# которое ктоли 0
# которое умень 0
# которое устан 0
# которое уноси 0
# которое будуч 0
# которое завед 0
# которое запис 0
# которое заним 0
# которое земля 1
# которое единс 0
# которое должн 0
# которое доить 1
# которое дейст 0
# которое делат 0
# которое дават 0
# которое функц 0
# которое чтоли 0
# которое испол 0
# которое измел 0
# которое являт 0
# которое целый 1
# которое элеме 0
# которой вызва 0
# которой выпек 0
# которой выстр 0
# которой высок 0
# которой выраб 0
# которой выигр 0
# которой власт 0
# которой входи 0
# которой вещес 0
# которой верте 0
# которой верхо 0
# которой верхн 0
# которой волос 2
# которой воспр 0
# которой внешн 0
# которой враща 0
# которой черни 0
# которой челов 0
# которой часть 1
# которой часто 1
# которой чтоли 0
# которой читат 0
# которой гость 1
# которой гонщи 0
# которой грави 0
# которой наход 0
# которой начин 0
# которой назва 0
# которой наряд 0
# которой навес 0
# которой нужны 0
# которой необх 0
# которой нижес 0
# которой завис 0
# которой заруб 0
# которой замен 0
# которой закан 0
# которой закре 0
# которой заклю 0
# которой заним 0
# которой задав 0
# которой загон 0
# которой загну 0
# которой загиб 0
# которой запая 0
# которой земля 1
# которой рассм 0
# которой распо 0
# которой разме 0
# которой разде 0
# которой разре 0
# которой работ 0
# которой равно 0
# которой регул 0
# которой резул 0
# которой измен 0
# которой измер 0
# которой изгот 0
# которой изобр 0
# которой испол 0
# которой исчис 0
# которой исход 0
# которой играт 0
# которой игрок 1
# которой имити 0
# которой иметь 1
# которой облад 0
# которой обычн 0
# которой объек 0
# которой образ 0
# которой обусл 0
# которой одина 0
# которой одева 0
# которой опыле 0
# которой основ 0
# которой остав 0
# которой ощуща 0
# которой откуп 0
# которой отдел 0
# которой созна 0
# которой созда 0
# которой созре 0
# которой совпа 0
# которой совер 0
# которой состо 0
# которой соста 0
# которой соотв 0
# которой содер 0
# которой соеди 0
# которой согла 0
# которой спере 0
# которой спиле 0
# которой спуск 0
# которой сущес 0
# которой стоят 0
# которой стяги 0
# которой струк 0
# которой связа 0
# которой свети 0
# которой сдела 0
# которой смачи 0
# которой салят 1
# которой самос 0
# которой среза 0
# которой сидет 0
# которой сходи 0
# которой слово 1
# которой участ 0
# которой умере 0
# которой ударя 0
# которой удовл 0
# которой узнат 0
# которой уплат 0
# которой управ 0
# которой указы 0
# которой укреп 0
# которой дорог 0
# которой должн 0
# которой движе 0
# которой двига 0
# которой дейст 0
# которой делат 0
# которой дальн 0
# которой данно 0
# которой кажды 0
# которой крепи 0
# которой клюшк 0
# которой кочев 0
# которой корол 0
# которой компь 0
# которой ктоли 0
# которой полый 1
# которой полож 0
# которой полив 0
# которой позво 0
# которой позна 0
# которой подав 0
# которой помещ 0
# которой понят 0
# которой понес 0
# которой покры 0
# которой произ 0
# которой проис 0
# которой просл 0
# которой прода 0
# которой прове 0
# которой прово 0
# которой прохо 0
# которой привя 0
# которой прина 0
# которой прикр 0
# которой прихо 0
# которой приме 0
# которой прису 0
# которой прекр 0
# которой предс 0
# которой предп 0
# которой прята 0
# которой падаю 0
# которой парик 0
# которой перес 0
# которой пишет 0
# которой питат 0
# которой пугат 0
# которой телах 1
# которой требо 0
# которой трати 0
# которой товар 1
# которой являт 0
# которой молод 0
# которой муэдз 0
# которой матем 0
# которой форми 0
# которой фести 0
# которой функц 0
# которой больш 0
# которой беско 0
# которой ездит 0
# которой харак 0
# которой аргум 0
# которой лежат 0
# которой жилой 1
# котором прохо 0
# котором произ 0
# котором проис 0
# котором пройд 0
# котором прода 0
# котором прави 0
# котором приго 0
# котором прибы 0
# котором предс 0
# котором подав 0
# котором подго 0
# котором подде 0
# котором полов 0
# котором похор 0
# котором посте 0
# котором повес 0
# котором перво 0
# котором перем 0
# котором парит 0
# котором готов 0
# котором говор 0
# котором глава 1
# котором однов 0
# котором основ 0
# котором осуще 0
# котором ощуща 0
# котором оказы 0
# котором обозн 0
# котором обнар 0
# котором обычн 0
# котором обесп 0
# котором опред 0
# котором отдел 0
# котором резко 1
# котором регис 0
# котором работ 0
# котором разли 0
# котором разви 0
# котором разъя 0
# котором распо 0
# котором рассм 0
# котором устан 0
# котором участ 0
# котором укреп 0
# котором выращ 0
# котором выраж 0
# котором выпол 0
# котором варят 1
# котором возде 0
# котором возмо 0
# котором враще 0
# котором врата 0
# котором вещес 0
# котором власт 0
# котором часть 1
# котором челов 0
# котором честв 0
# котором числи 0
# котором чувст 0
# котором чтоли 0
# котором терят 0
# котором танце 0
# котором крепи 0
# котором кисть 5
# котором качес 0
# котором качат 0
# котором кажды 0
# котором ктоли 0
# котором игрок 2
# котором играт 0
# котором изуча 0
# котором изобр 0
# котором излож 0
# котором изгот 0
# котором испол 0
# котором иммун 0
# котором молек 0
# котором музык 0
# котором мелки 0
# котором маски 0
# котором соста 0
# котором сосре 0
# котором совпа 0
# котором совер 0
# котором содер 0
# котором собир 0
# котором сопри 0
# котором сохра 0
# котором спосо 0
# котором стопа 1
# котором стави 0
# котором стрел 0
# котором схема 0
# котором скаля 0
# котором держа 0
# котором наруш 0
# котором наряд 0
# котором наход 0
# котором навед 0
# котором напис 0
# котором никто 1
# котором нужны 0
# котором непри 0
# котором неогр 0
# котором неэле 0
# котором носит 0
# котором запре 0
# котором заслу 0
# котором задат 0
# котором завис 0
# котором золят 1
# котором жизнь 1
# котором жидко 0
# котором аффик 0
# котором артис 0
# котором храня 0
# котором лежат 0
# котором лизин 0
# котором лидир 0
# котором лошад 0
# котором эмоци 0
# котором широк 0
# котором функц 0
# которому пере 0
# которому пров 0
# которому прой 0
# которому прои 0
# которому прох 0
# которому прот 0
# которому пред 0
# которому прав 0
# которому прип 0
# которому прик 0
# которому прич 0
# которому прид 0
# которому прин 0
# которому пору 0
# которому пове 0
# которому подъ 0
# которому подр 0
# которому свой 0
# которому стре 0
# которому стек 0
# которому степ 0
# которому стар 0
# которому сдел 0
# которому слеп 0
# которому след 0
# которому скол 0
# которому съез 0
# которому труд 0
# которому течь 1
# которому такж 0
# которому въез 0
# которому выго 0
# которому реко 0
# которому разл 0
# которому долж 0
# которому двиг 0
# которому дела 0
# которому осущ 0
# которому обой 0
# которому объе 0
# которому отре 0
# которому гада 0
# которому чтол 0
# которому чтот 0
# которому чело 0
# которому кото 0
# которому комп 0
# которому креп 0
# которому ясны 0
# которому узна 0
# которому изме 0
# которому изго 0
# которому блок 1
# которому нано 0
# которому мора 0
# которого выпи 0
# которого выхо 0
# которого води 0
# которого восп 0
# которого влия 0
# которого впре 0
# которого вход 0
# которого опре 0
# которого опис 0
# которого одно 0
# которого одна 1
# которого обра 0
# которого объе 0
# которого охла 0
# которого особ 0
# которого осно 0
# которого осущ 0
# которого огра 0
# которого ощущ 0
# которого отри 0
# которого отло 0
# которого отли 0
# которого чиха 0
# которого чита 0
# которого четы 0
# которого чере 0
# которого чтон 0
# которого чтол 0
# которого соде 0
# которого сове 0
# которого сост 0
# которого соса 0
# которого соед 0
# которого согл 0
# которого согн 0
# которого сокр 0
# которого суди 0
# которого судн 0
# которого субъ 0
# которого сним 0
# которого стро 0
# которого стоя 0
# которого счит 0
# которого слож 0
# которого связ 0
# которого спос 0
# которого смес 0
# которого нару 0
# которого набл 0
# которого напо 0
# которого нахо 0
# которого назв 0
# которого нано 0
# которого намн 0
# которого наст 0
# которого начи 0
# которого необ 0
# которого непо 0
# которого нест 0
# которого носи 0
# которого пост 0
# которого посы 0
# которого подт 0
# которого погл 0
# которого пола 0
# которого поле 1
# которого полу 0
# которого поми 0
# которого поме 0
# которого покр 0
# которого похо 0
# которого прим 0
# которого приг 0
# которого прис 0
# которого прик 0
# которого прин 0
# которого прио 0
# которого прев 0
# которого прои 0
# которого пров 0
# которого прод 0
# которого прям 0
# которого пере 0
# которого песн 0
# которого пара 0
# которого имет 0
# которого испо 0
# которого исчи 0
# которого изоб 0
# которого идти 1
# которого гото 0
# которого разм 0
# которого разв 0
# которого равн 0
# которого умер 0
# которого упот 0
# которого учас 0
# которого явля 0
# которого якоб 0
# которого есте 0
# которого лечь 1
# которого лете 0
# которого лежа 0
# которого лицо 1
# которого лоша 0
# которого любо 0
# которого кото 0
# которого комп 0
# которого ктол 0
# которого хара 0
# которого шама 0
# которого фрон 0
# которого мочь 2
# которого меня 0
# которого жени 0
# которого дела 0
# которого долж 0
# которого арми 0
# которого цикл 0
# которого защи 0
# которого заши 0
# которого точк 0
# которого благ 0
# которых челов 0
# которых число 1
# которых чтоли 0
# которых мучит 0
# которых печат 0
# которых перев 0
# которых прохо 0
# которых произ 0
# которых проис 0
# которых предн 0
# которых попер 0
# которых позво 0
# которых укреп 0
# которых отсут 0
# которых отриц 0
# которых опред 0
# которых осуще 0
# которых основ 0
# которых состо 0
# которых соста 0
# которых сорев 0
# которых содер 0
# которых скрыв 0
# которых склад 0
# которых субъе 0
# которых старш 0
# которых родит 0
# которых раскр 0
# которых изоли 0
# которых извле 0
# которых иметь 0
# которых дочер 0
# которых форми 0
# которых являт 0
# которых харак 0
# которых автор 1
# которых входи 0
# которых внешн 0
# которых выста 0
# которых ввест 0
# которых наблю 0
# которых набит 0
# которых неспо 0
# которых немин 0
# которых низки 0
# которых конец 1
# которых лишат 0
# которых лежат 0
# которых экран 0
# которых гидро 0
# которыхсубъек 0
# которые задав 0
# которые зачас 0
# которые мнени 0
# которые нужны 0
# которые надев 0
# которые напом 0
# которые некот 0
# которые норме 1
# которые распр 0
# которые разби 0
# которые разле 0
# которые регул 0
# которые попад 0
# которые польз 0
# которые позво 0
# которые подно 0
# которые прини 0
# которые прина 0
# которые прикр 0
# которые предс 0
# которые предо 0
# которые больш 0
# которые болез 0
# которые челов 0
# которые члени 0
# которые касат 0
# которые слива 0
# которые случа 0
# которые являт 0
# которые выбит 0
# которые возло 0
# которые вешае 0
# которые владе 0
# которые испол 0
# которые извес 0
# которые иметь 1
# которые центр 0
# которые указы 0
# которые услов 0
# которые однов 0
# которые обычн 0
# которые опред 0
# которые гаран 0
# который переп 0
# который произ 0
# который прода 0
# который прини 0
# который привы 0
# который предн 0
# который предс 0
# который преоб 0
# который прави 0
# который плати 0
# который посту 0
# который посте 0
# который поджи 0
# который получ 0
# который позво 0
# который стоят 0
# который следи 0
# который служи 0
# который счита 0
# который специ 0
# который спрое 0
# который сорти 0
# который созда 0
# который суеве 0
# который намаз 0
# который навеш 0
# который наход 0
# который нанос 0
# который нанес 0
# который накла 0
# который натян 0
# который напис 0
# который необх 0
# который невоз 0
# который разме 0
# который работ 0
# который религ 0
# который решаю 0
# который выдел 0
# который выраж 0
# который выраб 0
# который вклад 0
# который возгл 0
# который воспе 0
# который водит 0
# который волоч 0
# который верит 0
# который вноси 0
# который вмест 0
# который указы 0
# который ухажи 0
# который убира 0
# который обычн 0
# который отриц 0
# который оказы 0
# который опред 0
# который опуск 0
# который очища 0
# который ктоли 0
# который канал 1
# который колот 0
# который курящ 0
# который завер 0
# который завис 0
# который зажиг 0
# который заряж 0
# который захва 0
# который часто 2
# который челов 0
# который чтоли 0
# который делат 0
# который держа 0
# который добав 0
# который дават 0
# который жизнь 1
# который готов 0
# который говор 0
# который испол 0
# который иметь 1
# который требо 0
# который фетиш 0
# которым броса 0
# которым пугат 0
# которым произ 0
# которым проис 0
# которым проте 0
# которым прима 0
# которым присп 0
# которым прича 0
# которым привя 0
# которым покры 0
# которым перед 0
# которым вызыв 0
# которым восто 0
# которым украш 0
# которым укрыв 0
# которым удовл 0
# которым утвер 0
# которым учащи 0
# которым народ 0
# которым напол 0
# которым наход 0
# которым накры 0
# которым необх 0
# которым состо 0
# которым соотн 0
# которым снару 0
# которым служи 0
# которым сущес 0
# которым сатан 0
# которым досту 0
# которым должн 0
# которым дышат 0
# которым зажим 0
# которым запол 0
# которым забив 0
# которым готов 0
# которым оклик 0
# которым холод 0
# которым чтоли 0
# которым какая 0
# которым регул 0
# которыми обес 0
# которыми обыч 0
# которыми осып 0
# которыми осна 0
# которыми выст 0
# которыми встр 0
# которыми прои 0
# которыми покр 0
# которыми поль 0
# которыми чтол 1
# которыми соед 0
# которыми связ 0
# которыми ктол 0
# котор концент 0
# котор крестья 0
# котор действо 0
# котор распрос 0
# котор рабочий 1
# котор подвеси 0
# котор приноси 0
# котор изучать 0
# котор элемент 2
# котор человек 1
# котор цветоно 0
# котор собрать 1
# котор самолёт 1
# котор фигурны 0
# котор отпечат 0
# котор балерин 0
# котор течение 1
# которая выраж 0
# которая вычис 0
# которая возни 0
# которая вмест 0
# которая улучш 0
# которая упира 0
# которая участ 0
# которая ударя 0
# которая служи 0
# которая соотв 0
# которая совер 0
# которая содер 0
# которая заним 0
# которая замен 0
# которая доить 1
# которая должн 0
# которая делат 0
# которая держа 0
# которая окайм 0
# которая обесп 0
# которая общий 1
# которая подор 0
# которая подде 0
# которая поним 0
# которая посто 0
# которая повто 0
# которая прело 0
# которая являт 0
# которая испыт 0
# которая крепи 0
# которая разве 0
# которая расск 0
# которая распр 0
# которая руков 0
# которая целик 0
# которая нижни 0
# которая натяг 0
# которую носит 0
# которую натяг 0
# которую надев 0
# которую нужны 0
# которую невоз 0
# которую дуэля 0
# которую делит 0
# которую делат 0
# которую держа 0
# которую друга 0
# которую стави 0
# которую стрел 0
# которую собир 0
# которую снижа 0
# которую следо 0
# которую садит 0
# ...
# которой применяться 1
# которой прекращатьс 0
# которой представите 0
# которой предполагат 0
# которой парикмахерс 0
# которой пересекатьс 0
# которой требоваться 1
# которой математичес 0
# которой формировать 0
# которой характерный 2
# котором производить 0
# котором происходить 4
# котором продаваться 1
# котором приготовляю 0
# котором представить 1
# котором подготовлят 0
# котором поддерживат 0
# котором повествован 0
# котором повествоват 0
# котором первоначаль 0
# котором перемещатьс 0
# котором одновременн 0
# котором осуществлят 0
# котором оказываться 1
# котором обнаруживат 0
# котором обеспечиват 0
# котором регистриров 0
# котором развиваться 2
# котором разъяснятьс 0
# котором располагать 0
# котором расположена 1
# котором расположени 0
# котором рассматрива 0
# котором устанавлива 0
# котором укрепляться 1
# котором выращиватьс 0
# котором выполняться 1
# котором воздействие 1
# котором изображение 1
# котором изготовляют 0
# котором использован 0
# котором использоват 0
# котором исполняться 1
# котором музыкальный 1
# котором маскировать 0
# котором составитель 1
# котором сосредоточи 0
# котором совершаться 2
# котором содержаться 1
# котором соприкасают 0
# котором сохраняться 1
# котором схематическ 0
# котором неограничен 0
# котором неэлектриче 0
# котором заслушивать 0
# котором лизингополу 0
# котором эмоциональн 0
# которому пересажива 0
# которому проводитьс 0
# которому производит 0
# которому предостави 0
# которому предъявить 1
# которому правительс 0
# которому приписывае 0
# которому прикреплят 0
# которому причаливат 0
# которому принадлежа 0
# которому поверяться 1
# которому подъезжать 1
# которому свойственн 0
# которому стремиться 1
# которому рекомендов 0
# которому различатьс 0
# которому осуществля 0
# которому изготовляю 0
# которому изготавлив 0
# которого воспроизво 0
# которого впрессоват 0
# которого определить 1
# которого определять 0
# которого одновремен 0
# которого образовать 1
# которого охлаждение 1
# которого осуществля 0
# которого ограничива 0
# которого отложиться 1
# которого содержимый 8
# которого содержатьс 0
# которого совершатьс 0
# которого составлять 1
# которого соединятьс 0
# которого сокращатьс 0
# которого считыватьс 0
# которого напоминать 2
# которого находиться 2
# которого необходимы 0
# которого неподвижны 0
# которого постепенно 1
# которого подтвердит 0
# которого поглощатьс 0
# которого применятьс 0
# которого приготовля 0
# которого присваиват 0
# которого прикреплят 0
# которого принадлежа 0
# которого приобретаю 0
# которого производит 0
# которого происходит 0
# которого проводитьс 0
# которого прямоуголь 0
# которого перегонять 1
# которого перемещать 0
# которого переправля 0
# которого перестават 0
# которого паразитиро 0
# которого использова 0
# которого исчислятьс 0
# которого изображать 0
# которого готовиться 1
# которого развиватьс 0
# которого разворачив 0
# которого употребляю 0
# которого естественн 0
# которого характериз 0
# которого характерны 0
# которого характерно 1
# которого циклически 0
# которого зашифроват 0
# которых перевозитьс 0
# которых происходить 2
# которых преднамерен 0
# которых попеременно 1
# которых отсутствова 0
# которых осуществлят 0
# которых соревновать 0
# которых содержаться 1
# которых складыватьс 0
# которых раскрыватьс 0
# которых изолировать 1
# которых формировать 0
# которых характерный 1
# которых выставлятьс 0
# которых наблюдаться 1
# которых неспособный 1
# которых гидроксильн 0
# которыхсубъектопред 0
# которые распростран 0
# которые разбивается 2
# которые разлетаться 1
# которые регулироват 0
# которые пользоватьс 0
# которые принадлежат 0
# которые прикрепляют 0
# которые представлят 0
# которые предоставля 0
# которые болезненный 1
# которые использоват 0
# которые централизов 0
# которые одновременн 0
# которые гарантирова 0
# который перепрыгива 0
# который производить 2
# который продаваться 1
# который предназначи 0
# который представлен 0
# который преобразует 1
# который специализир 0
# который спроецирова 0
# который сортировать 1
# который навешиватьс 0
# который накладывать 0
# который необходимый 1
# который невозможный 1
# который размещаться 1
# который религиозный 1
# который вырабатыват 0
# который вкладыватьс 0
# который возглавлять 1
# который определятьс 0
# который завершаться 1
# который зависимость 1
# который добавляться 1
# который использоват 0
# который требоваться 1
# которым производить 1
# которым происходить 1
# которым приманивать 1
# которым приспосабли 0
# которым причаливают 0
# которым привязывать 0
# которым покрываться 1
# которым передаватьс 0
# которым удовлетворя 0
# которым утверждатьс 0
# которым необходимый 1
# которым соотноситьс 0
# которым существоват 0
# которым какаянибудь 1
# которыми обеспечива 0
# которыми встречатьс 0
# которыми производит 0
# которыми пользовать 0
# котор концентрирова 0
# котор распространят 0
# котор отпечатыватьс 0
# которая участвовать 1
# которая соответство 0
# которая обеспечиват 0
# которая поддерживат 0
# которая повторяться 1
# которая развешивать 0
# которая рассказыват 0
# которая распростран 0
# которая натягиватьс 0
# которую натягиватьс 0
# которую невозможный 1
# которую приходиться 1
# которую происходить 1
# которую пользовател 0
# которую векселедате 0
# которую вставляться 1
# которую вкладыватьс 0
# которую вделываться 1
# которую затруднятьс 0
# которую гарантирова 0
# которую увеличивать 0
# которую увеличиться 1
# котёл производиться 1
# котировка финансовы 0
# котельный установка 1
# которое проецировать 0
# которое предназначит 0
# которое выставляться 1
# которое обеспечивать 2
# которое образоваться 1
# которое складываться 1
# которое характеризов 0
# которое комментирова 0
# которое устанавливат 0
# которое записываться 1
# которое единственный 1
# которое функциониров 0
# которое использовать 1
# которой выстраиватьс 0
# которой вырабатывать 0
# которой воспроизводи 0
# которой гравировалас 0
# которой заканчиватьс 0
# которой закрепляться 1
# которой рассматриват 0
# которой располагатьс 0
# которой разделившиес 0
# которой равноудалены 1
# которой регулировщик 1
# которой изготовляютс 0
# которой изображаться 1
# которой использовать 0
# которой имитироватьс 0
# которой образоваться 1
# которой соответствов 0
# которой существовать 2
# которой самостоятель 0
# которой удовлетворят 0
# которой производитьс 0
# которой прославлятьс 0
# которой привязыватьс 0
# которой принадлежать 1
# которой прикреплятьс 0
# которой прикрепляютс 0
# которой прекращаться 1
# которой представител 0
# которой предполагать 1
# которой парикмахерск 0
# которой пересекаться 1
# которой математическ 0
# которой формироватьс 0
# котором производитьс 0
# котором приготовляют 0
# котором подготовлять 0
# котором поддерживать 0
# котором повествовани 0
# котором повествовать 0
# котором первоначальн 0
# котором перемещаться 1
# котором одновременно 1
# котором осуществлять 0
# котором обнаруживать 1
# котором обеспечивать 0
# котором регистрирова 0
# котором разъясняться 1
# котором располагатьс 0
# котором расположение 1
# котором рассматриват 0
# котором устанавливат 0
# котором выращиваться 1
# котором изготовляютс 0
# котором использовани 0
# котором использовать 0
# котором маскироватьс 0
# котором сосредоточит 0
# котором соприкасаютс 0
# котором схематически 1
# котором неограниченн 0
# котором неэлектричес 0
# котором заслушиватьс 0
# котором лизингополуч 0
# котором эмоциональны 0
# которому пересаживат 0
# которому проводиться 1
# которому производить 0
# которому предоставит 0
# которому правительст 0
# которому приписывает 0
# которому прикреплять 0
# которому причаливать 1
# которому принадлежат 0
# которому свойственны 0
# которому рекомендова 0
# которому различаться 1
# которому осуществлят 0
# которому изготовляют 0
# которому изготавлива 0
# которого воспроизвод 0
# которого впрессовать 1
# которого определятьс 0
# которого одновременн 0
# которого образоватьс 0
# которого осуществлят 0
# которого ограничиват 0
# которого содержаться 1
# которого совершаться 1
# которого соединяться 1
# которого сокращаться 1
# которого считываться 1
# которого необходимый 1
# которого неподвижный 1
# которого подтвердить 1
# которого поглощаться 1
# которого применяться 1
# которого приготовлят 0
# которого присваивать 0
# которого прикреплять 0
# которого принадлежат 0
# которого приобретают 0
# которого производить 1
# которого происходить 2
# которого проводиться 1
# которого прямоугольн 0
# которого перемещатьс 0
# которого переправляю 0
# которого переставать 1
# которого паразитиров 0
# которого использоват 0
# которого исчисляться 1
# которого изображатьс 0
# которого развиваться 1
# которого разворачива 0
# которого употребляют 0
# которого естественны 0
# которого характеризо 0
# которого характерный 3
# которого циклический 1
# которого зашифровать 1
# которых перевозиться 1
# которых преднамеренн 0
# которых отсутствоват 0
# которых осуществлять 1
# которых соревноватьс 0
# которых складываться 1
# которых раскрываться 1
# которых формироватьс 0
# которых выставляться 1
# которых гидроксильны 0
# которыхсубъектопреде 0
# которые распространя 0
# которые регулировать 1
# которые пользоваться 1
# которые принадлежать 1
# которые прикрепляютс 0
# которые представлять 0
# которые предоставлят 0
# которые использовать 0
# которые централизова 0
# которые одновременно 1
# которые гарантироват 0
# который перепрыгиват 0
# который предназначит 0
# который представлени 0
# который специализиру 0
# который спроецироват 0
# который навешиваться 1
# который накладыватьс 0
# который вырабатывать 1
# который вкладываться 1
# который определяться 1
# который использовать 0
# которым приспосаблив 0
# которым причаливаютс 0
# которым привязыватьс 0
# которым передаваться 1
# которым удовлетворят 0
# которым утверждаться 1
# которым соотноситься 1
# которым существовать 1
# которыми обеспечиват 0
# которыми встречаться 1
# которыми производить 0
# которыми пользоватьс 0
# котор концентрироват 0
# котор распространять 0
# котор отпечатываться 1
# которая соответствов 0
# которая обеспечивать 1
# которая поддерживать 1
# которая развешиватьс 0
# которая рассказывать 1
# которая распространя 0
# которая натягиваться 1
# которую натягиваться 1
# которую пользователь 2
# которую векселедател 0
# которую вкладываться 2
# которую затрудняться 1
# которую гарантироват 0
# которую увеличиватьс 0
# котировка финансовый 1
# которое проецироватьс 0
# которое предназначить 1
# которое характеризова 0
# которое комментироват 0
# которое устанавливать 1
# которое функционирова 0
# которой выстраиваться 1
# которой вырабатыватьс 0
# которой воспроизводит 0
# которой гравировалась 1
# которой заканчиваться 1
# которой рассматривать 0
# которой располагаться 1
# которой разделившиеся 1
# которой изготовляются 1
# которой использоватьс 0
# которой имитироваться 1
# которой соответствова 0
# которой самостоятельн 0
# которой удовлетворять 1
# которой производиться 1
# которой прославляться 1
# которой привязываться 1
# которой прикрепляться 1
# которой прикрепляются 1
# которой представитель 1
# которой парикмахерски 0
# которой математически 0
# которой формироваться 1
# котором производиться 3
# котором приготовляютс 0
# котором подготовлятьс 0
# котором поддерживатьс 0
# котором повествование 1
# котором повествоватьс 0
# котором первоначально 2
# котором осуществлятьс 0
# котором обеспечиватьс 0
# котором регистрироват 0
# котором располагаться 5
# котором рассматривать 0
# котором устанавливать 0
# котором изготовляются 1
# котором использование 1
# котором использоватьс 0
# котором маскироваться 1
# котором сосредоточить 2
# котором соприкасаются 1
# котором неограниченны 0
# котором неэлектрическ 0
# котором заслушиваться 1
# котором лизингополуча 0
# котором эмоциональный 1
# которому пересаживать 1
# которому производитьс 0
# которому предоставить 1
# которому правительств 0
# которому приписываетс 0
# которому прикреплятьс 0
# которому принадлежать 1
# которому свойственный 1
# которому рекомендоват 0
# которому осуществлять 0
# которому изготовляютс 0
# которому изготавливаю 0
# которого воспроизводи 0
# которого определяться 1
# которого одновременно 1
# которого образоваться 3
# которого осуществлять 0
# которого ограничивать 0
# которого приготовлять 0
# которого присваиватьс 0
# которого прикреплятьс 0
# которого принадлежать 1
# которого приобретаютс 0
# которого производитьс 0
# которого прямоугольни 0
# которого перемещаться 1
# которого переправляют 0
# которого паразитирова 0
# которого использовать 1
# которого изображаться 1
# которого разворачиват 0
# которого употребляютс 0
# которого естественный 1
# которого характеризов 0
# которых преднамеренно 1
# которых отсутствовать 1
# которых осуществлятьс 0
# которых соревноваться 1
# которых формироваться 1
# которых гидроксильный 1
# которыхсубъектопредел 0
# которые распространят 0
# которые регулироватьс 0
# которые прикрепляются 1
# которые представлятьс 0
# которые предоставлять 1
# которые использоватьс 0
# которые централизован 0
# которые гарантировать 1
# который перепрыгивать 1
# который предназначить 1
# который представление 1
# который специализируе 0
# который спроецировать 1
# который накладываться 1
# который использоватьс 0
# которым приспосаблива 0
# которым причаливаются 1
# которым привязываться 1
# которым удовлетворять 1
# которыми обеспечивать 0
# которыми производитьс 0
# которыми пользоваться 1
# котор концентрировать 0
# котор распространятьс 0
# которая соответствова 0
# которая развешиваться 1
# которая распространят 0
# которую векселедатель 1
# которую гарантировать 1
# которую увеличиваться 1
# которое проецироваться 1
# которое характеризоват 0
# которое комментировать 1
# которое функционироват 0
# которой вырабатываться 1
# которой воспроизводить 0
# которой рассматриватьс 0
# которой использоваться 1
# которой соответствоват 0
# которой самостоятельно 2
# которой парикмахерский 1
# которой математический 1
# котором приготовляются 1
# котором подготовляться 1
# котором поддерживаться 1
# котором повествоваться 1
# котором осуществляться 1
# котором обеспечиваться 1
# котором регистрировать 0
# котором рассматриватьс 0
# котором устанавливатьс 0
# котором использоваться 1
# котором неограниченный 1
# котором неэлектрически 0
# котором лизингополучат 0
# которому производиться 1
# которому правительство 1
# которому приписывается 1
# которому прикрепляться 2
# которому рекомендовать 0
# которому осуществлятьс 0
# которому изготовляются 1
# которому изготавливают 0
# которого воспроизводит 0
# которого осуществлятьс 0
# которого ограничиватьс 0
# которого приготовлятьс 0
# которого присваиваться 1
# которого прикрепляться 2
# которого приобретаются 1
# которого производиться 4
# которого прямоугольник 0
# которого переправляютс 0
# которого паразитироват 0
# которого использоватьс 0
# которого разворачивать 0
# которого употребляются 2
# которого характеризова 0
# которых осуществляться 2
# которыхсубъектопределя 0
# которые распространять 0
# которые регулироваться 1
# которые представляться 1
# которые использоваться 3
# которые централизованн 0
# который специализирует 0
# который использоваться 1
# которым приспосабливат 0
# которыми обеспечиватьс 0
# которыми производиться 3
# котор концентрироватьс 0
# котор распространяться 1
# которая соответствоват 0
# которая распространять 0
# которое характеризовать 0
# которое функционировать 1
# которой воспроизводитьс 0
# которой рассматриваться 1
# которой соответствовать 1
# котором регистрироватьс 0
# котором рассматриваться 1
# котором устанавливаться 1
# котором неэлектрический 1
# котором лизингополучате 0
# которому рекомендоватьс 0
# которому осуществляться 1
# которому изготавливаютс 0
# которого воспроизводить 1
# которого осуществляться 1
# которого ограничиваться 1
# которого приготовляться 1
# которого прямоугольники 1
# которого переправляются 1
# которого паразитировать 1
# которого использоваться 3
# которого разворачиватьс 0
# которого характеризоват 0
# которыхсубъектопределяе 0
# которые распространятьс 0
# которые централизованно 1
# который специализируетс 0
# которым приспосабливать 0
# которыми обеспечиваться 2
# котор концентрироваться 1
# которая соответствовать 1
# которая распространятьс 0
# которое характеризоватьс 0
# которой воспроизводиться 1
# котором регистрироваться 1
# котором лизингополучател 0
# которому рекомендоваться 1
# которому изготавливаются 1
# которого разворачиваться 1
# которого характеризовать 0
# которыхсубъектопределяет 0
# которые распространяться 1
# который специализируется 1
# которым приспосабливатьс 0
# которая распространяться 2
# которое характеризоваться 1
# котором лизингополучатель 1
# которого характеризоватьс 0
# которыхсубъектопределяетс 0
# которым приспосабливаться 1
# которого характеризоваться 2
# которыхсубъектопределяется 1
# которыхсубъектопределяется  0
# которыхсубъектопределяется р 0
# которыхсубъектопределяется ра 0
# которыхсубъектопределяется рас 0
# которыхсубъектопределяется раск 0
# которыхсубъектопределяется раскр 0
# которыхсубъектопределяется раскры 0
# которыхсубъектопределяется раскрыв 0
# которыхсубъектопределяется раскрыва 0
# которыхсубъектопределяется раскрыват 0
# которыхсубъектопределяется раскрывать 0
# которыхсубъектопределяется раскрыватьс 0
# которыхсубъектопределяется раскрываться 1

# %% [markdown]
# Напишем языковую модель на основе построенного словаря:

# %%
class LanguageModel: #предполагается, что слова лемматизированы перед тем, как поступают на вход языковой модели
    
    def __init__(self, vocab, n_gram=2, default_proba=0.01):
        self.trie = vocab
        self.def_proba = default_proba
        self.n = n_gram
        
    def update_vocab(self, sentence):
        text = ''.join(x for x in sentence if x not in punctuation)
        words = word_tokenize(text, language="russian")
        words = [word for word in words if word not in stops]
        text = ' '.join(words)
        doc = nlp(text)
        words = [word.lemma_ for word in nlp(text)]
    
        for word in words:
            self.trie.add(word)
        
        for i in range(len(words) - 1):
            curr_bigram = words[i] + " " + words[i + 1]
            self.trie.add(curr_bigram, is_bigram=True)
        
    def calculate_freq(self, word):
        array = self.trie.search_by_prefix(word)
        word_freq = 0
        words = []
        freqs = []
        for w, vec, freq in array:
            words.append(w)
            freqs.append(freq)
        
        for i in range(len(words)):
            if words[i] == word:
                word_freq = freqs[i]
        
        return word_freq
    
    def calculate_bigram_proba(self, bigram):
        bigram_freq = self.calculate_freq(bigram)
        
        if not bigram_freq:
            return self.def_proba
        
        first_word = bigram.split()[0]
        word_freq = self.calculate_freq(first_word)
                
        if not word_freq:
            return default_proba # на самом деле, этот случай возможен, только если и биграмма имеет нулевую частотность
        
        return bigram_freq / word_freq
    
    def calculate_proba(self, sentence):
        proba = 1
        
        text = ''.join(x for x in sentence if x not in punctuation)
        words = word_tokenize(text, language="russian")
        words=[word.lower() for word in words if word.isalpha()]
        words = [word for word in words if word not in stops]
        text = ' '.join(words)
        doc = nlp(text)
        words = [word.lemma_ for word in nlp(text)]
        
        if len(words) < self.n:
            proba = 0
        
        for i in range(len(words) - 1):
            curr_bigram = words[i] + " " + words[i + 1]
            proba *= self.calculate_bigram_proba(curr_bigram)
        
        return proba

# %% [markdown]
# Обучим модель на построенном словаре, потестируем на примерах:

# %%
l_model = LanguageModel(wt)
print(l_model.calculate_proba("Кислый цитрусовый фрукт"))
# Out:
# 0.0001

# %%
print(l_model.calculate_proba("цитрусовый фрукт"))
# Out:
# 0.01

# %%
print(l_model.calculate_proba("дед мороз"))
# Out:
# 0.01

# %%
print(l_model.calculate_freq("дед"))
# Out:
# 6

# %%
print(l_model.calculate_freq("дед мороз"))
# Out:
# 0

# %%
print(l_model.calculate_freq("перемещение верхом"))
# Out:
# 0

# %%
for word, vec, freq in wt.search_by_prefix("перемещение"):
    print(word, freq)
# Out:
# перемещение 78
# перемещение  0
# перемещение п 0
# перемещение к 0
# перемещение а 0
# перемещение о 0
# перемещение е 0
# перемещение т 0
# перемещение ч 0
# перемещение с 0
# перемещение в 0
# перемещение ж 0
# перемещение ц 0
# перемещение и 0
# перемещение м 0
# перемещение н 0
# перемещение д 0
# перемещение б 0
# перемещение г 0
# перемещение у 0
# перемещение ш 0
# перемещение пе 0
# перемещение по 0
# перемещение пр 0
# перемещение ко 0
# перемещение ку 0
# перемещение ка 0
# перемещение ат 0
# перемещение от 0
# перемещение оч 0
# перемещение об 0
# перемещение ос 0
# перемещение ед 0
# перемещение тр 0
# перемещение те 0
# перемещение та 0
# перемещение че 0
# перемещение ча 0
# перемещение сп 0
# перемещение су 0
# перемещение св 0
# перемещение см 0
# перемещение ве 0
# перемещение вп 0
# перемещение во 0
# перемещение жи 0
# перемещение це 0
# перемещение цв 0
# перемещение из 0
# перемещение ма 0
# перемещение на 0
# перемещение до 0
# перемещение др 0
# перемещение бе 0
# перемещение бо 0
# перемещение гр 0
# перемещение га 0
# перемещение ус 0
# перемещение ша 0
# перемещение пер 0
# перемещение пос 0
# перемещение пов 0
# перемещение пом 0
# перемещение про 0
# перемещение при 0
# перемещение ког 0
# перемещение куд 0
# перемещение как 0
# перемещение атм 0
# перемещение ато 0
# перемещение отк 0
# перемещение оче 0
# перемещение обы 0
# перемещение осу 0
# перемещение еди 0
# перемещение тра 0
# перемещение тел 0
# перемещение так 0
# перемещение чег 0
# перемещение чел 0
# перемещение час 0
# перемещение спу 0
# перемещение суб 0
# перемещение све 0
# перемещение сме 0
# перемещение вер 0
# перемещение впл 0
# перемещение вой 0
# перемещение жид 0
# перемещение жив 0
# перемещение цел 0
# перемещение цве 0
# перемещение изд 0
# перемещение изм 0
# перемещение мак 0
# перемещение нас 0
# перемещение нак 0
# перемещение наи 0
# перемещение нап 0
# перемещение дос 0
# перемещение дог 0
# перемещение дру 0
# перемещение бег 1
# перемещение бол 0
# перемещение гру 0
# перемещение газ 1
# перемещение усл 0
# перемещение шаж 0
# перемещение пере 0
# перемещение посе 0
# перемещение пове 0
# перемещение помо 0
# перемещение прос 0
# перемещение прис 0
# перемещение кого 0
# перемещение куда 0
# перемещение каки 0
# перемещение како 0
# перемещение атмо 0
# перемещение атом 1
# перемещение отку 0
# перемещение очен 0
# перемещение обыч 0
# перемещение осущ 0
# перемещение един 0
# перемещение тран 0
# перемещение тело 2
# перемещение такж 0
# перемещение чего 0
# перемещение чело 0
# перемещение част 0
# перемещение спущ 0
# перемещение субъ 0
# перемещение свет 0
# перемещение смещ 0
# перемещение верх 2
# перемещение впла 0
# перемещение войс 0
# перемещение жидк 0
# перемещение живо 0
# перемещение цель 1
# перемещение цвет 0
# перемещение изде 0
# перемещение изме 0
# перемещение макр 0
# перемещение насе 0
# перемещение накл 0
# перемещение наим 0
# перемещение напр 0
# перемещение дост 0
# перемещение дого 0
# перемещение друг 0
# перемещение боль 0
# перемещение груз 2
# перемещение усло 0
# перемещение шажо 0
# перемещение перев 0
# перемещение перен 0
# перемещение перед 0
# перемещение посел 0
# перемещение повер 0
# перемещение помощ 0
# перемещение прост 0
# перемещение присп 0
# перемещение когол 0
# перемещение кудал 0
# перемещение каких 0
# перемещение какой 1
# перемещение каког 0
# перемещение атмос 0
# перемещение откуд 0
# перемещение очень 1
# перемещение обычн 0
# перемещение осуще 0
# перемещение едини 0
# перемещение транс 0
# перемещение также 1
# перемещение чегол 0
# перемещение челов 0
# перемещение часть 2
# перемещение части 0
# перемещение спуще 0
# перемещение субъе 0
# перемещение свето 0
# перемещение смеще 0
# перемещение вплав 0
# перемещение войск 0
# перемещение жидки 0
# перемещение жидко 0
# перемещение живой 1
# перемещение цветн 0
# перемещение издел 0
# перемещение измен 0
# перемещение макро 0
# перемещение насел 0
# перемещение накло 0
# перемещение наиме 0
# перемещение напри 0
# перемещение досту 0
# перемещение доста 0
# перемещение догов 0
# перемещение другу 0
# перемещение больш 0
# перемещение услов 0
# перемещение шажок 1
# перемещение перево 0
# перемещение перено 0
# перемещение перене 0
# перемещение передв 0
# перемещение поселе 0
# перемещение поверх 0
# перемещение помощь 1
# перемещение простр 0
# перемещение приспо 0
# перемещение коголи 0
# перемещение кудали 0
# перемещение какихл 0
# перемещение какого 0
# перемещение атмосф 0
# перемещение откуда 0
# перемещение обычно 1
# перемещение осущес 0
# перемещение единиц 0
# перемещение трансп 0
# перемещение чеголи 0
# перемещение челове 0
# перемещение частиц 0
# перемещение спущен 0
# перемещение субъек 0
# перемещение светов 0
# перемещение смещен 0
# перемещение вплавь 1
# перемещение войско 2
# перемещение жидкий 1
# перемещение жидкос 0
# перемещение цветни 0
# перемещение издели 0
# перемещение измене 0
# перемещение макрос 0
# перемещение населе 0
# перемещение наклон 1
# перемещение наимен 0
# перемещение наприм 0
# перемещение доступ 0
# перемещение достав 0
# перемещение догово 0
# перемещение другую 1
# перемещение больши 0
# перемещение услови 0
# перемещение перевоз 0
# перемещение перенос 1
# перемещение перенес 0
# перемещение передви 0
# перемещение поселен 0
# перемещение поверхн 0
# перемещение простра 0
# перемещение приспос 0
# перемещение коголиб 0
# перемещение кудалиб 0
# перемещение какихли 0
# перемещение какогол 0
# перемещение атмосфе 0
# перемещение откудал 0
# перемещение осущест 0
# перемещение единица 1
# перемещение транспо 0
# перемещение чеголиб 0
# перемещение человек 1
# перемещение частица 1
# перемещение спущенн 0
# перемещение субъект 2
# перемещение светово 0
# перемещение смещени 0
# перемещение жидкост 0
# перемещение цветник 1
# перемещение изделие 1
# перемещение изменен 0
# перемещение макроск 0
# перемещение населен 0
# перемещение наимень 0
# перемещение наприме 0
# перемещение доступу 1
# перемещение доставк 0
# перемещение договор 0
# перемещение больший 1
# перемещение условие 1
# перемещение перевозк 0
# перемещение перенесе 0
# перемещение передвиж 0
# перемещение поселени 0
# перемещение поверхно 0
# перемещение простран 0
# перемещение приспосо 0
# перемещение коголибо 5
# перемещение кудалибо 1
# перемещение какихлиб 0
# перемещение какоголи 0
# перемещение атмосфер 0
# перемещение откудали 0
# перемещение осуществ 0
# перемещение транспор 0
# перемещение чеголибо 5
# перемещение спущенны 0
# перемещение световой 1
# перемещение смещение 1
# перемещение жидкость 1
# перемещение изменени 0
# перемещение макроско 0
# перемещение населени 0
# перемещение наименьш 0
# перемещение например 1
# перемещение доставка 1
# перемещение договорё 0
# перемещение перевозка 1
# перемещение перенесен 0
# перемещение передвиже 0
# перемещение поселение 1
# перемещение поверхнос 0
# перемещение пространс 0
# перемещение приспособ 0
# перемещение какихлибо 1
# перемещение какоголиб 0
# перемещение атмосфере 1
# перемещение откудалиб 0
# перемещение осуществл 0
# перемещение транспорт 0
# перемещение спущенных 1
# перемещение изменение 1
# перемещение макроскоп 0
# перемещение население 1
# перемещение наименьши 0
# перемещение договорён 0
# перемещение перенесени 0
# перемещение передвижен 0
# перемещение поверхност 0
# перемещение пространст 0
# перемещение приспособл 0
# перемещение какоголибо 1
# перемещение откудалибо 1
# перемещение осуществля 0
# перемещение транспорти 0
# перемещение транспортн 0
# перемещение макроскопи 0
# перемещение наименьший 1
# перемещение договорённ 0
# перемещение перенесение 2
# перемещение передвижени 0
# перемещение поверхность 1
# перемещение пространств 0
# перемещение приспособле 0
# перемещение осуществлят 0
# перемещение транспортир 0
# перемещение транспортны 0
# перемещение макроскопич 0
# перемещение договорённо 0
# перемещение передвижение 1
# перемещение пространство 1
# перемещение приспособлен 0
# перемещение осуществлять 1
# перемещение транспортиро 0
# перемещение транспортный 1
# перемещение макроскопиче 0
# перемещение договорённос 0
# перемещение приспособлени 0
# перемещение транспортиров 0
# перемещение макроскопичес 0
# перемещение договорённост 0
# перемещение приспособление 1
# перемещение транспортировк 0
# перемещение макроскопическ 0
# перемещение договорённость 1
# перемещение транспортировка 1
# перемещение макроскопически 0
# перемещение макроскопический 1

# %%
print(l_model.calculate_freq("перемещение верх"))
# Out:
# 2

# %%
print(l_model.calculate_proba("перемещение верх"))
# Out:
# 0.02564102564102564

# %%
print(l_model.calculate_freq("перемещение"))
# Out:
# 78

# %% [markdown]
# Подсоединим к spell-checker-у языковую модель:

# %%
class Spell_checker:
    
    def __init__(self, lang_model, topn=5, max_number_of_errors=10):
        self.trie = lang_model.trie
        self.closest_str = []
        self.lang_model = lang_model
        self.topn = topn #сколько значений возвращает
        self.max_num_err = max_number_of_errors #максимальное количество опечаток, которое 
                                                #может допустить пользователь в одном слове
            
    def update_vocab(self, sentence):
        self.lang_model.update_vocab(sentence)

    def update_values_before_new_word(self):
        self.closest_str = [("", self.max_num_err)] * self.topn #в нём хранятся пары, состоящие из слов и соотв расстояний

    def dfs(self, tmp_node, word, flag): #находит все слова в дереве на расстоянии <= максимального возможного кол-ва опечаток
        # flag indicates whether to use an improved version of the Levenshtein's algorithm
        if tmp_node.value is not None:
            vocab_word = tmp_node._get_prefix()
            number_of_cols = len(vocab_word) + 1
            number_of_rows = len(word) + 1 if not flag else 2
            d_levenshtein = [[0] * number_of_cols for i in range(number_of_rows)]
            for i in range(number_of_rows):
                d_levenshtein[i][0] = i
            for j in range(number_of_cols):
                d_levenshtein[0][j] = j
            for i in range(1, len(word) + 1):
                for j in range(1, number_of_cols):
                    delta = 1
                    if word[i - 1] == vocab_word[j - 1]:
                        delta = 0
                    curr_row = i if not flag else 1
                    d_levenshtein[curr_row][j] = min(d_levenshtein[curr_row][j - 1] + 1, d_levenshtein[curr_row - 1][j] + 1,
                                                     d_levenshtein[curr_row - 1][j - 1] + delta)
                if flag:
                    for j in range(number_of_cols):
                        d_levenshtein[0][j] = d_levenshtein[1][j]
                        d_levenshtein[1][0] += 1
            if d_levenshtein[number_of_rows - 1][len(vocab_word)] <= self.max_num_err:
                curr_dist = d_levenshtein[number_of_rows - 1][len(vocab_word)]
                found_index = -1
                for k in range(self.topn):
                    if curr_dist <= self.closest_str[k][1]:
                        found_index = k
                        break
                if found_index != -1:
                    curr_value = self.closest_str[found_index]
                    for k in range(found_index + 1, self.topn):
                        tmp = self.closest_str[k]
                        self.closest_str[k] = curr_value
                        curr_value = tmp
                        
                    self.closest_str[found_index] = (vocab_word, curr_dist)

        if len(tmp_node.children):
            for child in tmp_node.children.values():
                self.dfs(child, word, flag)

    def search_closest_words(self, word, flag):#ищет ближайшее слово(!) по метрике Левенштейна
        # flag indicates whether to use an improved version of the Levenshtein's algorithm
        self.update_values_before_new_word()
        
        self.dfs(self.trie.root, word, flag)
        
        return sorted(self.closest_str, key=lambda pair: pair[1])
    
    def search_closest_sentence(self, sentence, flag): #в зависимости от длины определения, рассматривается разное количество случаев
        text = ''.join(x for x in sentence if x not in punctuation)
        words = word_tokenize(text, language="russian")
        words=[word.lower() for word in words if word.isalpha()]
        words = [word for word in words if word not in stops]
        text = ' '.join(words)
        doc = nlp(text)
        words = [word.lemma_ for word in nlp(text)]
        
        num_top = 2
        if len(words) <= 5:
            num_top = 5
        elif len(words) <= 10:
            num_top = 3
        
        poss_words = []
        for word in words:
            self.update_values_before_new_word()
            poss_words.append(self.search_closest_words(word, flag)[:num_top])
        
        poss_sent_with_proba = []
        
        def generator(curr_len=0, coord=[0] * len(words)):
            if curr_len == len(words):
                possible_sent = ""
                for i in range(len(words)):
                    x = coord[i]
                    possible_sent += poss_words[i][x][0] + " "
                proba = self.lang_model.calculate_proba(possible_sent)
                poss_sent_with_proba.append((possible_sent, proba))
                return
            else:
                for i in range(num_top):
                    coord[curr_len] = i
                    generator(curr_len + 1, coord)
        
        generator()
        
        sorted(poss_sent_with_proba, key=lambda pair: pair[1], reverse=True)
        closest_sentence = poss_sent_with_proba[0][0]

        return closest_sentence

# %%
sp_checker = Spell_checker(l_model)

# %%
print(sp_checker.search_closest_sentence("кислый цитрусовый фрукт", False))
print(sp_checker.search_closest_sentence("кислый цитрусовый фрукт", True))
# Out:
# кислый цифровой фрукт
# кислый цифровой фрукт

# %%
tests = [
    "Митрополит возложил на голову Его Императорского Величества ворону",
    "Товарищ Сталин принял польского осла",
    "вызывается в качестве сидетеля",
    "Ячейка обществп",
    "Солнце встанет на двп часа позже",
    "Уставшие гбаза от войнв",
    "Зорко одно шишь сердце",
    "Тестируема исправлерие опечатк",
    "Опечатка опнчатке рознь",
    "Человек чловеку сад",
    "Южный полбс в снегах",
    "Намеренное придумываеие опечатое вредит вашему здоровью:)",
    "По рзелульаттам илссеовадний одонго анлигйсокго унвиертисета, не иеемт занчнеия, в кокам пряокде рсапожолены бкувы в солве",
]

defs_with_err = [
    "это тип двиэения и измееения в прирьде и обществуе, связанныы с переходоп от одного квчества, сосрояния к друшому, от старлго к новому",
    "угол между вртикалью и пооскостью врщения колесс",
    "Ветхое, почтт разваливаюдееся строените",
    "соединени из трёх молекул кислороэа",
    "чистосердечеое признание",
    "чем закрыцвают винр",
    "предмет, на кроторый наручнна проволок",
    "Отпечатлк на песк",
]

# %%
for test in tests:
    print(sp_checker.search_closest_sentence(test, True))
# Out:
# митрополит возложить голов императорский величество ворон
# товарищ сталин принять польский посол
# вызывать качестве свидетель
# ячейка общество
# солнце устать два час позже
# устать газа войне
# ярко одно шить сердце
# теорема исправление печать
# перчатка оплате жизнь
# человек человеке сад
# южный полюс снега
# намеренный придумывать оператор вредить ваш здоровье
# результат рассеивание долго английский университет цвет англия рок ряде расположены скулы голове

# %%
for test in defs_with_err:
    print(sp_checker.search_closest_sentence(test, True))
# Out:
# это тип движениях изменении природа общество связанный переходной одного качество состоянии другому строго новый
# угол вертикаль плоскость армения колесо
# ветхий почта разваливаться строение
# соединении три молекула кислород
# чистосердечие признание
# закрывать вино
# предмет который наручник проволока
# отпечаток пуск

# %% [markdown]
# Результаты почти такие же, если всегда рассматривать num_top = 2

# %%
class Spell_checker1:
    
    def __init__(self, lang_model, topn=5, max_number_of_errors=10):
        self.trie = lang_model.trie
        self.closest_str = []
        self.lang_model = lang_model
        self.topn = topn #сколько значений возвращает
        self.max_num_err = max_number_of_errors #максимальное количество опечаток, которое 
                                                #может допустить пользователь в одном слове
    
    def update_vocab(self, sentence):
        self.lang_model.update_vocab(sentence)

    def update_values_before_new_word(self):
        self.closest_str = [("", self.max_num_err)] * self.topn #в нём хранятся пары, состоящие из слов и соотв расстояний

    def dfs(self, tmp_node, word, flag): #находит все слова в дереве на расстоянии <= максимального возможного кол-ва опечаток
        # flag indicates whether to use an improved version of the Levenshtein's algorithm
        if tmp_node.value is not None:
            vocab_word = tmp_node._get_prefix()
            number_of_cols = len(vocab_word) + 1
            number_of_rows = len(word) + 1 if not flag else 2
            d_levenshtein = [[0] * number_of_cols for i in range(number_of_rows)]
            for i in range(number_of_rows):
                d_levenshtein[i][0] = i
            for j in range(number_of_cols):
                d_levenshtein[0][j] = j
            for i in range(1, len(word) + 1):
                for j in range(1, number_of_cols):
                    delta = 1
                    if word[i - 1] == vocab_word[j - 1]:
                        delta = 0
                    curr_row = i if not flag else 1
                    d_levenshtein[curr_row][j] = min(d_levenshtein[curr_row][j - 1] + 1, d_levenshtein[curr_row - 1][j] + 1,
                                                     d_levenshtein[curr_row - 1][j - 1] + delta)
                if flag:
                    for j in range(number_of_cols):
                        d_levenshtein[0][j] = d_levenshtein[1][j]
                        d_levenshtein[1][0] += 1
            if d_levenshtein[number_of_rows - 1][len(vocab_word)] <= self.max_num_err:
                curr_dist = d_levenshtein[number_of_rows - 1][len(vocab_word)]
                found_index = -1
                for k in range(self.topn):
                    if curr_dist <= self.closest_str[k][1]:
                        found_index = k
                        break
                if found_index != -1:
                    curr_value = self.closest_str[found_index]
                    for k in range(found_index + 1, self.topn):
                        tmp = self.closest_str[k]
                        self.closest_str[k] = curr_value
                        curr_value = tmp
                        
                    self.closest_str[found_index] = (vocab_word, curr_dist)

        if len(tmp_node.children):
            for child in tmp_node.children.values():
                self.dfs(child, word, flag)

    def search_closest_words(self, word, flag):#ищет ближайшее слово(!) по метрике Левенштейна
        # flag indicates whether to use an improved version of the Levenshtein's algorithm
        self.update_values_before_new_word()
        
        self.dfs(self.trie.root, word, flag)
        
        return sorted(self.closest_str, key=lambda pair: pair[1])
    
    def search_closest_sentence(self, sentence, flag, num_top=2): #!!! Для каждого слова рассматриваю по 2 первых варианта (из расчёта, что 2^20 ~10^6)
        text = ''.join(x for x in sentence if x not in punctuation)
        words = word_tokenize(text, language="russian")
        words=[word.lower() for word in words if word.isalpha()]
        words = [word for word in words if word not in stops]
        text = ' '.join(words)
        doc = nlp(text)
        words = [word.lemma_ for word in nlp(text)]
        
        poss_words = []
        for word in words:
            self.update_values_before_new_word()
            poss_words.append(self.search_closest_words(word, flag)[:num_top])
        
        poss_sent_with_proba = []
        
        def generator(curr_len=0, coord=[0] * len(words)):
            if curr_len == len(words):
                possible_sent = ""
                for i in range(len(words)):
                    x = coord[i]
                    possible_sent += poss_words[i][x][0] + " "
                proba = self.lang_model.calculate_proba(possible_sent)
                poss_sent_with_proba.append((possible_sent, proba))
                return
            else:
                for i in range(num_top):
                    coord[curr_len] = i
                    generator(curr_len + 1, coord)
        
        generator()
        
        sorted(poss_sent_with_proba, key=lambda pair: pair[1], reverse=True)
        closest_sentence = poss_sent_with_proba[0][0]

        return closest_sentence

# %%
sp_checker1 = Spell_checker1(l_model)
print(sp_checker1.search_closest_sentence("кислый цитрусовый фрукт", False))
print(sp_checker1.search_closest_sentence("кислый цитрусовый фрукт", True))
# Out:
# кислый цифровой фрукт
# кислый цифровой фрукт

# %%
for test in tests:
    print(sp_checker1.search_closest_sentence(test, True))
# Out:
# митрополит возложить голов императорский величество ворон
# товарищ сталин принять польский посол
# вызывать качестве свидетель
# ячейка общество
# солнце устать два час позже
# устать газа войне
# ярко одно шить сердце
# теорема исправление печать
# перчатка оплате жизнь
# человек человеке сад
# южный полюс снега
# намеренный придумывать оператор вредить ваш здоровье
# результат рассеивание долго английский университет цвет англия рок ряде расположены скулы голове

# %%
for test in defs_with_err:
    print(sp_checker1.search_closest_sentence(test, True))
# Out:
# это тип движениях изменении природа общество связанный переходной одного качество состоянии другому строго новый
# угол вертикаль плоскость армения колесо
# ветхий почта разваливаться строение
# соединении три молекула кислород
# чистосердечие признание
# закрывать вино
# предмет который наручник проволока
# отпечаток пуск

# %% [markdown]
# Сохраним модель:

# %%
import pickle

with open('spell_checker.pickle', 'wb') as file:
    pickle.dump(sp_checker, file)
    
with open('spell_checker1.pickle', 'wb') as file:
    pickle.dump(sp_checker1, file)
